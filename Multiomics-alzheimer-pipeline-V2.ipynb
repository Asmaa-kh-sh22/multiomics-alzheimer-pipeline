# %% [markdown]
# # 1: Set Working Directory to Data Folder

# %%
# Change to the folder where our data files are located
import os

# Set the path to your data folder
data_folder = r'C:\Users\a\AlzheimerResearch'

# Change to that directory
os.chdir(data_folder)

# Confirm we're in the right place
print(f"Current working directory: {os.getcwd()}")
print("\nFiles in this folder:")
for file in os.listdir():
    print(f"  - {file}")
# Out:
# Current working directory: C:\Users\a\AlzheimerResearch
#
# Files in this folder:
#   - .ipynb_checkpoints
#   - AD_sumstats_Jansenetal_2019sept.txt
#   - differential_expression_results_full.csv
#   - enrichment_results
#   - enrichment_results_candidates_only
#   - GPL5175-3188.txt
#   - GSE131617-GPL5175_series_matrix.txt
#   - Multiomics-alzheimer-pipeline.ipynb
#   - multi_omics_overlap_genes.csv
#   - pca_plot.png
#   - permutation_test.png
#   - significant_genes_FDR05.csv
#   - significant_genes_p001.csv
#   - significant_genes_p005.csv
#   - volcano_plot_p005.png

# %% [markdown]
# # 2: Setup - Install and Import Required Libraries

# %%
# Install the packages we need for bioinformatics analysis
# !pip install bioinfokit
# !pip install gseapy
# !pip install dask[dataframe]

# Import all the libraries we'll use throughout this project
import pandas as pd  # For working with data tables
import numpy as np  # For mathematical operations
import matplotlib.pyplot as plt  # For making plots
import seaborn as sns  # For making plots

# Import specific tools for our analysis
import gseapy as gp  # For gene enrichment analysis

# Let us know everything loaded correctly
print("All libraries imported successfully!")
# Out:
# Requirement already satisfied: bioinfokit in c:\users\a\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: pandas in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (2.3.3)
# Requirement already satisfied: numpy in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (3.10.9)
# Requirement already satisfied: scipy in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (1.17.1)
# Requirement already satisfied: scikit-learn in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (1.6.1)
# Requirement already satisfied: seaborn in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (0.13.2)
# Requirement already satisfied: matplotlib-venn in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (1.1.2)
# Requirement already satisfied: tabulate in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (0.8.10)
# Requirement already satisfied: statsmodels in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (0.14.6)
# Requirement already satisfied: textwrap3 in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (0.9.2)
# Requirement already satisfied: adjustText in c:\users\a\anaconda3\lib\site-packages (from bioinfokit) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\a\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\a\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\a\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\a\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\a\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (9.4.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\a\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\a\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a\anaconda3\lib\site-packages (from pandas->bioinfokit) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\a\anaconda3\lib\site-packages (from pandas->bioinfokit) (2026.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\a\anaconda3\lib\site-packages (from scikit-learn->bioinfokit) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\a\anaconda3\lib\site-packages (from scikit-learn->bioinfokit) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\a\anaconda3\lib\site-packages (from statsmodels->bioinfokit) (1.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\a\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->bioinfokit) (1.16.0)
# Requirement already satisfied: gseapy in c:\users\a\anaconda3\lib\site-packages (1.1.10)
# Requirement already satisfied: numpy>=1.13.0 in c:\users\a\anaconda3\lib\site-packages (from gseapy) (1.26.4)
# Requirement already satisfied: scipy in c:\users\a\anaconda3\lib\site-packages (from gseapy) (1.17.1)
# Requirement already satisfied: pandas in c:\users\a\anaconda3\lib\site-packages (from gseapy) (2.3.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\a\anaconda3\lib\site-packages (from gseapy) (3.10.9)
# Requirement already satisfied: requests in c:\users\a\anaconda3\lib\site-packages (from gseapy) (2.34.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\a\anaconda3\lib\site-packages (from matplotlib>=2.2->gseapy) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\a\anaconda3\lib\site-packages (from matplotlib>=2.2->gseapy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a\anaconda3\lib\site-packages (from matplotlib>=2.2->gseapy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\a\anaconda3\lib\site-packages (from matplotlib>=2.2->gseapy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\a\anaconda3\lib\site-packages (from matplotlib>=2.2->gseapy) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\a\anaconda3\lib\site-packages (from matplotlib>=2.2->gseapy) (9.4.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\a\anaconda3\lib\site-packages (from matplotlib>=2.2->gseapy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\a\anaconda3\lib\site-packages (from matplotlib>=2.2->gseapy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a\anaconda3\lib\site-packages (from pandas->gseapy) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\a\anaconda3\lib\site-packages (from pandas->gseapy) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\a\anaconda3\lib\site-packages (from requests->gseapy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\a\anaconda3\lib\site-packages (from requests->gseapy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\a\anaconda3\lib\site-packages (from requests->gseapy) (1.26.16)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\a\anaconda3\lib\site-packages (from requests->gseapy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\a\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->gseapy) (1.16.0)
# Requirement already satisfied: dask[dataframe] in c:\users\a\anaconda3\lib\site-packages (2023.6.0)
# Requirement already satisfied: click>=8.0 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (2023.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (26.2)
# Requirement already satisfied: partd>=1.2.0 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (6.0.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (1.26.4)
# Requirement already satisfied: pandas>=1.3 in c:\users\a\anaconda3\lib\site-packages (from dask[dataframe]) (2.3.3)
# Requirement already satisfied: colorama in c:\users\a\anaconda3\lib\site-packages (from click>=8.0->dask[dataframe]) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\a\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[dataframe]) (3.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\a\anaconda3\lib\site-packages (from pandas>=1.3->dask[dataframe]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a\anaconda3\lib\site-packages (from pandas>=1.3->dask[dataframe]) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\a\anaconda3\lib\site-packages (from pandas>=1.3->dask[dataframe]) (2026.2)
# Requirement already satisfied: locket in c:\users\a\anaconda3\lib\site-packages (from partd>=1.2.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\a\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->dask[dataframe]) (1.16.0)
# C:\Users\a\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# All libraries imported successfully!

# %% [markdown]
# # 3: Load and Filter GWAS Data for Significant Variants

# %%
# Load the GWAS summary statistics file and keep only significant variants
# This file contains genetic data from Jansen et al. 2019 study

import pandas as pd
import os

# Specify the name of your GWAS file (with the .txt extension)
file_name = 'AD_sumstats_Jansenetal_2019sept.txt'

# Check if the file exists in the current folder
if os.path.exists(file_name):
    print(f"Found file: {file_name}")
else:
    print(f"ERROR: File '{file_name}' not found in the current folder!")
    print(f"Current folder is: {os.getcwd()}")

# Set the significance threshold (standard GWAS threshold)
pval_threshold = 5e-8  # This means p-value < 0.00000005

# The file is huge (1.8 GB!), so we'll read it in chunks to avoid crashing
chunksize = 1_000_000  # Process 1 million rows at a time

# Create an empty list to store significant variants
significant_hits = []

# Read the file chunk by chunk and filter for significant p-values
for chunk in pd.read_csv(file_name, sep='\t', chunksize=chunksize):
    # Keep only rows where p-value is less than our threshold
    sig_chunk = chunk[chunk['P'] < pval_threshold]
    significant_hits.append(sig_chunk)

# Combine all the significant chunks into one dataframe
gwas_significant_df = pd.concat(significant_hits, ignore_index=True)

print("SUCCESS!")
print(f"Number of significant hits: {len(gwas_significant_df)}")

# Show the first few rows to see what we got
gwas_significant_df.head()
# Out:
# Found file: AD_sumstats_Jansenetal_2019sept.txt
# SUCCESS!
# Number of significant hits: 2394
#        uniqID.a1a2  CHR         BP A1 A2         SNP         Z             P  \
# 0  1:161155392_A_G    1  161155392  A  G   rs4575098  6.369505  1.896396e-10
# 1  1:161156033_A_C    1  161156033  A  C  rs11585858  6.217633  5.047090e-10
# 2  1:207656050_C_T    1  207656050  C  T   rs6690215  5.453618  4.935515e-08
# 3  1:207679307_A_G    1  207679307  A  G   rs4844600  7.718582  1.176308e-14
# 4  1:207684192_T_G    1  207684192  T  G  rs12037841  6.350595  2.144842e-10
#
#      Nsum       Neff   dir       EAF      BETA        SE
# 0  434326  427808.62  ?+++  0.228026  0.016412  0.002577
# 1  434938  428415.10  ?+++  0.226625  0.016044  0.002580
# 2  436498  429961.08  ?+++  0.442624  0.011840  0.002171
# 3  433906  427392.40  ?+++  0.187204  0.021401  0.002773
# 4  381966  380696.97  ??++  0.171990  0.019285  0.003037

# %% [markdown]
# # 4: Load Transcriptomics Data from GEO

# %%
# Specify the name of your transcriptomics file (with .txt extension)
geo_file_name = "GSE131617-GPL5175_series_matrix.txt"

# Check if file exists
if os.path.exists(geo_file_name):
    print(f"Found file: {geo_file_name}")
else:
    print(f"ERROR: File '{geo_file_name}' not found!")

print("Loading transcriptomics data...")

# Load the data (skipping the metadata header lines that start with '!')
geo_matrix = pd.read_csv(geo_file_name, sep='\t', comment='!', header=0)

print("Transcriptomics data loaded successfully!")
print(f"Data shape: {geo_matrix.shape}")  # (Number of genes, Number of samples)

# Get the list of all sample column names (all columns except the first one)
all_sample_columns = geo_matrix.columns.tolist()[1:]
print(f"\nTotal number of sample columns: {len(all_sample_columns)}")
print(f"First 10 samples: {all_sample_columns[:10]}")
print(f"Last 10 samples: {all_sample_columns[-10:]}")

# Show the first few rows
geo_matrix.head()
# Out:
# Found file: GSE131617-GPL5175_series_matrix.txt
# Loading transcriptomics data...
# Transcriptomics data loaded successfully!
# Data shape: (22011, 214)
#
# Total number of sample columns: 213
# First 10 samples: ['GSM3790983', 'GSM3790984', 'GSM3790985', 'GSM3790986', 'GSM3790987', 'GSM3790988', 'GSM3790989', 'GSM3790990', 'GSM3790991', 'GSM3790992']
# Last 10 samples: ['GSM3791186', 'GSM3791187', 'GSM3791188', 'GSM3791189', 'GSM3791190', 'GSM3791191', 'GSM3791192', 'GSM3791193', 'GSM3791194', 'GSM3791195']
#     ID_REF  GSM3790983  GSM3790984  GSM3790985  GSM3790986  GSM3790987  \
# 0  2315554     6.43891     6.40143     6.68846     6.87754     7.01006
# 1  2315633     6.83356     6.86543     6.81464     7.06805     7.07767
# 2  2315674     6.79662     6.75745     6.98996     7.10421     7.09086
# 3  2315739     6.98153     6.65715     6.95574     7.14944     7.10217
# 4  2315894     8.47884     8.03744     8.68579     8.29076     8.31406
#
#    GSM3790988  GSM3790989  GSM3790990  GSM3790991  ...  GSM3791186  \
# 0     6.58444     6.55972     6.80588     6.86953  ...     6.47897
# 1     7.00740     6.95387     7.00008     7.01288  ...     7.17508
# 2     6.80098     6.93557     7.03011     7.15481  ...     6.87195
# 3     6.93502     7.36532     7.17295     7.12044  ...     6.90233
# 4     7.67433     8.29112     8.19051     8.44127  ...     7.65482
#
#    GSM3791187  GSM3791188  GSM3791189  GSM3791190  GSM3791191  GSM3791192  \
# 0     6.28043     6.65118     6.37871     6.86058     6.93216     6.48653
# 1     6.91513     6.73574     6.71180     6.85567     6.77573     6.59228
# 2     6.73450     6.67723     6.64036     6.84911     7.12525     6.75529
# 3     6.88897     6.90831     6.60863     6.77811     7.15875     6.86929
# 4     8.38338     8.57364     8.47330     8.75975     8.73779     8.21996
#
#    GSM3791193  GSM3791194  GSM3791195
# 0     6.75165     6.37197     6.84974
# 1     6.72161     6.59368     6.77830
# 2     7.01555     6.62437     6.88948
# 3     6.84764     6.83913     7.11398
# 4     8.71742     8.36763     8.84304
#
# [5 rows x 214 columns]

# %% [markdown]
# # 5: Check Data Quality and Basic Statistics

# %%
print("=== DATA QUALITY CHECK ===\n")

# Check for missing values (empty cells)
missing_count = geo_matrix.isnull().sum().sum()
print(f"Total missing values in dataset: {missing_count}")

if missing_count > 0:
    print("There are missing values!")
else:
    print("No missing values found!")

# Look at basic statistics of the expression values
# This tells us the range and distribution of our data
print("\n=== BASIC STATISTICS ===")
print("Statistics for expression data across all samples:")
stats = geo_matrix.iloc[:, 1:].describe().loc[['mean', 'std', 'min', 'max']]
print(stats)

# Check if values are already log-transformed
# Microarray data is usually already log2-transformed if values are between 0-16
print("\n=== CHECKING DATA SCALE ===")
min_val = geo_matrix.iloc[:, 1:].min().min()
max_val = geo_matrix.iloc[:, 1:].max().max()
print(f"Minimum expression value: {min_val:.2f}")
print(f"Maximum expression value: {max_val:.2f}")

if max_val < 20:
    print("Data appears to be already log-transformed (values are in a reasonable range)")
else:
    print("Data might need log transformation (values are very large)")
# Out:
# === DATA QUALITY CHECK ===
#
# Total missing values in dataset: 0
# No missing values found!
#
# === BASIC STATISTICS ===
# Statistics for expression data across all samples:
#       GSM3790983  GSM3790984  GSM3790985  GSM3790986  GSM3790987  GSM3790988  \
# mean    6.798851    6.807900    6.739291    6.739435    6.713747    6.855238
# std     2.005450    2.054167    1.990027    1.974685    1.991123    2.060872
# min     1.027120    0.956423    0.979166    0.962488    0.979410    0.910553
# max    13.610800   13.604200   13.377000   13.404900   13.464700   13.424200
#
#       GSM3790989  GSM3790990  GSM3790991  GSM3790992  ...  GSM3791186  \
# mean    6.769638    6.744128    6.717067    6.876608  ...    6.832585
# std     1.956998    1.967014    1.961794    2.046667  ...    2.036489
# min     1.039770    1.055620    0.846108    0.895800  ...    0.964261
# max    13.354900   13.323800   13.297700   13.473700  ...   13.367900
#
#       GSM3791187  GSM3791188  GSM3791189  GSM3791190  GSM3791191  GSM3791192  \
# mean    6.863029    6.832756    6.844018    6.733488    6.750875    6.823855
# std     2.025625    2.030103    2.004193    1.987572    2.024087    2.056131
# min     0.699559    1.095270    0.860456    1.037400    0.877658    0.948135
# max    13.643200   13.482200   13.560400   13.545300   13.538900   13.495500
#
#       GSM3791193  GSM3791194  GSM3791195
# mean    6.785946    6.833053    6.734859
# std     1.980907    2.057598    2.009391
# min     0.932012    0.934468    0.818570
# max    13.497300   13.586900   13.462500
#
# [4 rows x 213 columns]
#
# === CHECKING DATA SCALE ===
# Minimum expression value: 0.63
# Maximum expression value: 13.72
# Data appears to be already log-transformed (values are in a reasonable range)

# %% [markdown]
# # 6: Visualize Data Distribution

# %%
import matplotlib.pyplot as plt

# Take one sample and plot its distribution
sample_data = geo_matrix.iloc[:, 10].values  # Pick the 10th sample as an example

plt.figure(figsize=(10, 5))
plt.hist(sample_data, bins=50, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Distribution of Expression Values (One Sample)')
plt.xlabel('Expression Value')
plt.ylabel('Frequency (Number of Genes)')
plt.grid(axis='y', alpha=0.3)
plt.show()

print("If the distribution looks bell-shaped (normal), the data is good!")
print("If it's very skewed, we need transformation.")
# Out:
# If the distribution looks bell-shaped (normal), the data is good!
# If it's very skewed, we need transformation.

# %% [markdown]
# # 7: Check Sample Correlations to Find Outliers

# %%
import seaborn as sns

print("Calculating correlations between all samples...")

# Calculate how correlated each sample is with every other sample
sample_correlation = geo_matrix.iloc[:, 1:].corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(12, 10))
sns.heatmap(sample_correlation, cmap='coolwarm', center=0.9, 
            cbar_kws={'label': 'Correlation'})
plt.title('Sample Correlation Heatmap - Looking for Outliers')
plt.tight_layout()
plt.show()

print("\nWhat to look for:")
print("- Most samples should be red/orange (high correlation ~0.9-1.0)")
print("- Blue samples = potential outliers (low correlation)")
print("- Samples within the same group (Control or AD) should cluster together")
# Out:
# Calculating correlations between all samples...
# What to look for:
# - Most samples should be red/orange (high correlation ~0.9-1.0)
# - Blue samples = potential outliers (low correlation)
# - Samples within the same group (Control or AD) should cluster together

# %% [markdown]
# # 8: Normalize the Data

# %%
from sklearn.preprocessing import StandardScaler

print("Normalizing data...")
print("This makes each gene have mean=0 and standard deviation=1")

# Save the gene IDs before normalization
gene_ids = geo_matrix.iloc[:, 0]

# Normalize: for each gene, subtract mean and divide by standard deviation
scaler = StandardScaler()
expression_data_normalized = scaler.fit_transform(geo_matrix.iloc[:, 1:].T).T

# Create a new dataframe with normalized values
geo_matrix_normalized = pd.DataFrame(expression_data_normalized,
                                    columns=geo_matrix.columns[1:])
geo_matrix_normalized.insert(0, 'ID_REF', gene_ids.values)

print("Normalization complete!")
print(f"Normalized data shape: {geo_matrix_normalized.shape}")

# Check that normalization worked (mean should be ~0, std should be ~1)
print("\nVerifying normalization:")
print(f"Mean of normalized data: {geo_matrix_normalized.iloc[:, 1:].mean().mean():.6f} (should be close to 0)")
print(f"Std of normalized data: {geo_matrix_normalized.iloc[:, 1:].std().mean():.6f} (slightly below 1 expected: pandas uses ddof=1, sklearn uses ddof=0)")

# Show first few rows
geo_matrix_normalized.head()
# Out:
# Normalizing data...
# This makes each gene have mean=0 and standard deviation=1
# Normalization complete!
# Normalized data shape: (22011, 214)
#
# Verifying normalization:
# Mean of normalized data: 0.000000 (should be close to 0)
# Std of normalized data: 0.958369 (slightly below 1 expected: pandas uses ddof=1, sklearn uses ddof=0)
#     ID_REF  GSM3790983  GSM3790984  GSM3790985  GSM3790986  GSM3790987  \
# 0  2315554   -1.160757   -1.328676   -0.042722    0.804396    1.398113
# 1  2315633   -0.306460   -0.146729   -0.401287    0.868796    0.917011
# 2  2315674   -0.560336   -0.732918    0.291519    0.794904    0.736084
# 3  2315739   -0.124597   -1.734211   -0.252570    0.708593    0.474034
# 4  2315894    0.219629   -1.048675    0.814272   -0.320794   -0.253844
#
#    GSM3790988  GSM3790989  GSM3790990  GSM3790991  ...  GSM3791186  \
# 0   -0.508753   -0.619504    0.483344    0.768510  ...   -0.981280
# 1    0.564820    0.296530    0.528133    0.592286  ...    1.405227
# 2   -0.541126    0.051877    0.468419    1.017847  ...   -0.228432
# 3   -0.355386    1.779817    0.825253    0.564692  ...   -0.517597
# 4   -2.092023   -0.319759   -0.608849    0.111677  ...   -2.148082
#
#    GSM3791187  GSM3791188  GSM3791189  GSM3791190  GSM3791191  GSM3791192  \
# 0   -1.870781   -0.209744   -1.430466    0.728412    1.049105   -0.947410
# 1    0.102366   -0.796731   -0.916717   -0.195646   -0.596302   -1.515747
# 2   -0.834036   -1.086367   -1.248816   -0.329065    0.887606   -0.742435
# 3   -0.583891   -0.487924   -1.974973   -1.133993    0.754791   -0.681546
# 4   -0.054662    0.492024    0.203711    1.026786    0.963687   -0.524228
#
#    GSM3791193  GSM3791194  GSM3791195
# 0    0.240383   -1.460662    0.679846
# 1   -0.867550   -1.508731   -0.583421
# 2    0.404268   -1.319268   -0.151195
# 3   -0.788976   -0.831204    0.532636
# 4    0.905157   -0.099918    1.266109
#
# [5 rows x 214 columns]

# %% [markdown]
# # 8.5: Extract Sample IDs and Braak Stages from Metadata

# %%
print("=== EXTRACTING BRAAK STAGE LABELS FROM METADATA ===\n")

import re

gsm_ids = []
braak_stages = []

with open("GSE131617-GPL5175_series_matrix.txt", "r") as f:
    for line in f:
        line = line.strip()

        # Extract GSM accession IDs (preserves column order)
        if line.startswith("!Sample_geo_accession"):
            gsm_ids = re.findall(r'"(GSM\d+)"', line)

        # Extract Braak stage values
        if line.startswith("!Sample_characteristics_ch1") and "braak nft stage" in line:
            braak_stages = re.findall(r'"braak nft stage:\s*([^"]+)"', line)

        # Stop once we hit the data matrix
        if line.startswith('"ID_REF"') or line.startswith("ID_REF"):
            break

# Verify lengths match
print(f"GSM IDs found:      {len(gsm_ids)}")
print(f"Braak labels found: {len(braak_stages)}")

if len(gsm_ids) != len(braak_stages):
    print("WARNING: counts do not match — check file parsing!")
else:
    print("✓ Counts match — safe to proceed\n")

# Build a lookup dictionary: GSM_ID → Braak stage string
sample_braak = dict(zip(gsm_ids, braak_stages))

# Show the unique Braak values present
unique_stages = sorted(set(braak_stages))
print("Unique Braak stage values found in file:")
for s in unique_stages:
    count = braak_stages.count(s)
    print(f"  '{s}' → {count} samples")
    
# Also extract sample titles for region filtering
titles_raw = []
with open("GSE131617-GPL5175_series_matrix.txt", "r") as f:
    for line in f:
        if line.startswith("!Sample_title"):
            titles_raw = re.findall(r'"([^"]+)"', line)
            break

sample_titles = dict(zip(gsm_ids, titles_raw))
print(f"\nSample titles extracted: {len(sample_titles)}")
print("Example:", list(sample_titles.items())[0])
# Out:
# === EXTRACTING BRAAK STAGE LABELS FROM METADATA ===
#
# GSM IDs found:      213
# Braak labels found: 213
# ✓ Counts match — safe to proceed
#
# Unique Braak stage values found in file:
#   '0' → 39 samples
#   'I-II' → 60 samples
#   'III-IV' → 57 samples
#   'V-VI' → 57 samples
#
# Sample titles extracted: 213
# Example: ('GSM3790983', 'Braak_NFT_stage_0_subject-01_EC (gene-level)')

# %% [markdown]
# # 9: Define Control vs Alzheimer's Groups

# %%
# 9: Define Control vs Alzheimer's Groups
# Using Entorhinal Cortex (EC) only — first affected region in AD
# 13 Braak-0 subjects × 1 region = 13 controls
# 19 Braak V-VI subjects × 1 region = 19 AD cases

print("=== SAMPLE GROUPS DEFINED BY BRAAK LABEL (EC only) ===\n")

available_columns = set(geo_matrix_normalized.columns[1:])

# Controls: Braak 0, EC only
control_samples = [
    gsm for gsm, stage in sample_braak.items()
    if stage.strip() == "0"
    and gsm in available_columns
    and "EC" in sample_titles.get(gsm, "")
]

# AD cases: Braak V-VI, EC only
ad_samples = [
    gsm for gsm, stage in sample_braak.items()
    if stage.strip() == "V-VI"
    and gsm in available_columns
    and "EC" in sample_titles.get(gsm, "")
]

print(f"Control samples (Braak 0, EC):    {len(control_samples)}")
print(f"AD samples (Braak V-VI, EC):      {len(ad_samples)}")
print(f"Total used in analysis:           {len(control_samples) + len(ad_samples)}")

assert len(control_samples) == 13, \
    f"Expected 13 controls, got {len(control_samples)}"
assert len(ad_samples) == 19, \
    f"Expected 19 AD samples, got {len(ad_samples)}"

print("\n✓ Counts verified: 13 controls, 19 AD cases (Entorhinal Cortex)")
print("\nFirst 5 control GSMs:", control_samples[:5])
print("First 5 AD GSMs:     ", ad_samples[:5])
# Out:
# === SAMPLE GROUPS DEFINED BY BRAAK LABEL (EC only) ===
#
# Control samples (Braak 0, EC):    13
# AD samples (Braak V-VI, EC):      19
# Total used in analysis:           32
#
# ✓ Counts verified: 13 controls, 19 AD cases (Entorhinal Cortex)
#
# First 5 control GSMs: ['GSM3790983', 'GSM3790986', 'GSM3790989', 'GSM3790992', 'GSM3790995']
# First 5 AD GSMs:      ['GSM3791139', 'GSM3791142', 'GSM3791145', 'GSM3791148', 'GSM3791151']

# %% [markdown]
# # 9.1: PCA Analysis to Check Sample Clustering

# %%
from sklearn.decomposition import PCA

print("=== PRINCIPAL COMPONENT ANALYSIS ===\n")
print("Purpose: Check if Control and AD samples cluster separately")
print("         (validates our group comparison)\n")

# Perform PCA on normalized data
# Transpose: genes as features, samples as observations
pca = PCA(n_components=2)
pca_coords = pca.fit_transform(geo_matrix_normalized.iloc[:, 1:].T)

# Create sample labels and colors
all_sample_names = geo_matrix_normalized.columns[1:].tolist()
sample_labels = []
sample_colors = []

for sample in all_sample_names:
    if sample in control_samples:
        sample_labels.append('Control')
        sample_colors.append('blue')
    elif sample in ad_samples:
        sample_labels.append('AD')
        sample_colors.append('red')
    else:
        sample_labels.append('Not Used')
        sample_colors.append('lightgray')

# Plot
plt.figure(figsize=(10, 8))
for label, color in [('Control', 'blue'), ('AD', 'red'), ('Not Used', 'lightgray')]:
    mask = [l == label for l in sample_labels]
    if any(mask):
        plt.scatter(pca_coords[mask, 0], pca_coords[mask, 1],
                   c=color, label=label, s=100, alpha=0.7, edgecolors='black')

plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% variance)', fontsize=12)
plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% variance)', fontsize=12)
plt.title('PCA: Sample Clustering by Disease State', fontsize=14, fontweight='bold')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('pca_plot.png', dpi=150)
plt.show()

print(f"PC1 explains {pca.explained_variance_ratio_[0]*100:.1f}% of variance")
print(f"PC2 explains {pca.explained_variance_ratio_[1]*100:.1f}% of variance")
print("Saved as 'pca_plot.png'")
print("\nInterpretation:")
print("  - If Control and AD samples separate → good signal")
print("  - If they overlap completely → weak signal or batch effects")
# Out:
# === PRINCIPAL COMPONENT ANALYSIS ===
#
# Purpose: Check if Control and AD samples cluster separately
#          (validates our group comparison)
# PC1 explains 32.0% of variance
# PC2 explains 12.1% of variance
# Saved as 'pca_plot.png'
#
# Interpretation:
#   - If Control and AD samples separate → good signal
#   - If they overlap completely → weak signal or batch effects

# %% [markdown]
# # 9.2: Calculate Log2 Fold Changes on ORIGINAL Data

# %%
print("=== CALCULATING TRUE LOG2 FOLD CHANGES ===\n")
print("IMPORTANT: Using ORIGINAL log2 expression values")
print("           (BEFORE z-score normalization)\n")

# Use the ORIGINAL geo_matrix (contains log2 expression values)
control_original = geo_matrix[control_samples]
ad_original = geo_matrix[ad_samples]

true_log2_fc = []

for idx in range(len(geo_matrix)):
    # Get ORIGINAL log2 expression values
    control_vals = control_original.iloc[idx].values
    ad_vals = ad_original.iloc[idx].values
    
    # Calculate mean for each group
    mean_control = np.mean(control_vals)
    mean_ad = np.mean(ad_vals)
    
    # TRUE log2 fold change = difference in log2 expression
    log2_fc = mean_ad - mean_control
    true_log2_fc.append(log2_fc)

print(f"Calculated log2 fold changes for {len(true_log2_fc)} genes")
print(f"Range: {min(true_log2_fc):.3f} to {max(true_log2_fc):.3f}")
print("\nThese values represent TRUE biological fold changes!")
# Out:
# === CALCULATING TRUE LOG2 FOLD CHANGES ===
#
# IMPORTANT: Using ORIGINAL log2 expression values
#            (BEFORE z-score normalization)
#
# Calculated log2 fold changes for 22011 genes
# Range: -1.944 to 0.954
#
# These values represent TRUE biological fold changes!

# %% [markdown]
# # 10: Perform Differential Expression Analysis (T-tests)

# %%
from scipy import stats  # ← ADD THIS LINE

print("\n" + "="*40)
print("=== DIFFERENTIAL EXPRESSION ANALYSIS ===")
print("="*40)
print("\nComparing Control vs AD samples using t-tests...\n")

# Get normalized data for statistical testing
control_data = geo_matrix_normalized[control_samples]
ad_data = geo_matrix_normalized[ad_samples]

# Get gene IDs
gene_ids = geo_matrix_normalized['ID_REF']

# INITIALIZE EMPTY LISTS (this was missing!)
p_values = []
t_statistics = []
effect_sizes = []

print("Running t-tests for all genes...")

for idx in range(len(geo_matrix_normalized)):
    # Use NORMALIZED data for t-test (this is standard practice)
    control_values = control_data.iloc[idx].values
    ad_values = ad_data.iloc[idx].values
    
    # Perform independent samples t-test
    t_stat, p_val = stats.ttest_ind(ad_values, control_values)
    
    # Calculate effect size (Cohen's d)
    pooled_std = np.sqrt((np.var(control_values) + np.var(ad_values)) / 2)
    if pooled_std > 0:
        cohens_d = (np.mean(ad_values) - np.mean(control_values)) / pooled_std
    else:
        cohens_d = 0
    
    # Store results
    p_values.append(p_val)
    t_statistics.append(t_stat)
    effect_sizes.append(cohens_d)

# Create results dataframe with CORRECTED log2 fold changes
results_df = pd.DataFrame({
    'Gene_ID': gene_ids,
    'log2_fold_change': true_log2_fc,  # ✓ CORRECTED: Using original data
    'effect_size': effect_sizes,        # ✓ NEW: Cohen's d from normalized data
    't_statistic': t_statistics,
    'p_value': p_values
})

print(f"\n✓ T-tests complete for {len(results_df)} genes!")
print(f"\nGenes with p < 0.05 (uncorrected): {sum(results_df['p_value'] < 0.05)}")
print(f"Genes with p < 0.001 (uncorrected): {sum(results_df['p_value'] < 0.001)}")

print("\n=== TOP 10 MOST SIGNIFICANT GENES ===")
top10 = results_df.nsmallest(10, 'p_value')
print(top10[['Gene_ID', 'log2_fold_change', 'effect_size', 'p_value']].to_string(index=False))
# Out:
# ========================================
# === DIFFERENTIAL EXPRESSION ANALYSIS ===
# ========================================
#
# Comparing Control vs AD samples using t-tests...
#
# Running t-tests for all genes...
#
# ✓ T-tests complete for 22011 genes!
#
# Genes with p < 0.05 (uncorrected): 1273
# Genes with p < 0.001 (uncorrected): 26
#
# === TOP 10 MOST SIGNIFICANT GENES ===
#  Gene_ID  log2_fold_change  effect_size  p_value
#  2406420         -0.329521    -2.100563 0.000004
#  3634656         -0.424467    -1.980616 0.000005
#  2337217          0.250256     1.698465 0.000077
#  2708855         -0.440508    -1.587962 0.000116
#  2958232          0.410112     1.663959 0.000117
#  3139580         -0.185887    -1.657646 0.000124
#  2888284         -0.341652    -1.553671 0.000196
#  3624513          0.603654     1.590845 0.000203
#  3820342         -0.174243    -1.563267 0.000205
#  3448744         -0.342785    -1.485507 0.000215

# %% [markdown]
# # 11: Apply Multiple Testing Correction (FDR)

# %%
# Applying False Discovery Rate (FDR) correction
# This is CRITICAL because we're testing thousands of genes
# Without correction, we'd have many false positives

from statsmodels.stats.multitest import multipletests

print("=== MULTIPLE TESTING CORRECTION ===\n")
print("Applying Benjamini-Hochberg FDR correction...")
print("This controls the expected proportion of false discoveries")

# Apply FDR correction (Benjamini-Hochberg method)
rejected, p_adjusted, _, _ = multipletests(results_df['p_value'], 
                                            method='fdr_bh', 
                                            alpha=0.05)

# Add adjusted p-values to results
results_df['p_adjusted'] = p_adjusted

# Count significant genes at different thresholds
sig_005 = sum(results_df['p_adjusted'] < 0.05)
sig_001 = sum(results_df['p_adjusted'] < 0.01)
sig_0001 = sum(results_df['p_adjusted'] < 0.001)

print(f"\nSignificant genes after FDR correction:")
print(f"  FDR < 0.05: {sig_005} genes")
print(f"  FDR < 0.01: {sig_001} genes")
print(f"  FDR < 0.001: {sig_0001} genes")

# Show comparison before and after correction
print(f"\nComparison:")
print(f"  Before correction (p < 0.05): {sum(results_df['p_value'] < 0.05)} genes")
print(f"  After correction (FDR < 0.05): {sig_005} genes")
print(f"  This shows how many were likely false positives!")
# Out:
# === MULTIPLE TESTING CORRECTION ===
#
# Applying Benjamini-Hochberg FDR correction...
# This controls the expected proportion of false discoveries
#
# Significant genes after FDR correction:
#   FDR < 0.05: 0 genes
#   FDR < 0.01: 0 genes
#   FDR < 0.001: 0 genes
#
# Comparison:
#   Before correction (p < 0.05): 1273 genes
#   After correction (FDR < 0.05): 0 genes
#   This shows how many were likely false positives!

# %% [markdown]
# # 12: Identify Significantly Dysregulated Genes

# %%
# Primary: FDR-corrected threshold (rigorous, but expected to be
# overly conservative given the small sample size, n=32).
# Fallback: uncorrected exploratory threshold, used for all
# downstream analysis (documented explicitly as exploratory throughout).

print("=== IDENTIFYING SIGNIFICANT GENES ===\n")

# --- Step 1: FDR-corrected threshold ---
fdr_threshold = 0.05
significant_genes_fdr = results_df[results_df['p_adjusted'] < fdr_threshold].copy()
significant_genes_fdr = significant_genes_fdr.sort_values('p_adjusted')

print(f"Significant genes (FDR < {fdr_threshold}): {len(significant_genes_fdr)}")

if len(significant_genes_fdr) == 0:
    print("  → No probes survive FDR correction.")
    print("  → With n/m = 32/22,011 ≈ 0.0015, this is a structural")
    print("    consequence of the high-dimensional low-sample regime,")
    print("    not a pipeline failure (see Section 10, Limitations).")

# Save the (possibly empty) FDR-corrected result for the record
results_df.to_csv('differential_expression_results_full.csv', index=False)
significant_genes_fdr.to_csv('significant_genes_FDR05.csv', index=False)

# --- Step 2: Exploratory uncorrected threshold (used downstream) ---
print("\n" + "-"*50)
print("Falling back to uncorrected p < 0.05 for exploratory analysis")
print("(explicitly flagged as exploratory throughout this study).")
print("-"*50 + "\n")

pval_threshold = 0.05
significant_genes = results_df[results_df['p_value'] < pval_threshold].copy()
significant_genes = significant_genes.sort_values('p_value')

print(f"Significant genes (uncorrected p < {pval_threshold}): {len(significant_genes)}")

upregulated = significant_genes[significant_genes['log2_fold_change'] > 0]
downregulated = significant_genes[significant_genes['log2_fold_change'] < 0]

print(f"\n  Upregulated in AD (higher expression):   {len(upregulated)} genes")
print(f"  Downregulated in AD (lower expression):  {len(downregulated)} genes")

print("\n=== TOP 10 MOST SIGNIFICANT GENES (exploratory) ===")
if len(significant_genes) > 0:
    print(significant_genes[['Gene_ID', 'log2_fold_change', 'p_value']].head(10).to_string(index=False))
else:
    print("No significant genes found at this threshold either.")

# Save exploratory results — this is the set used in all downstream steps
significant_genes.to_csv('significant_genes_p005.csv', index=False)
print(f"\nResults saved to 'significant_genes_p005.csv'")

significant_gene_ids = significant_genes['Gene_ID'].tolist()
print(f"\n{len(significant_gene_ids)} genes will be used for downstream GWAS integration.")
# Out:
# === IDENTIFYING SIGNIFICANT GENES ===
#
# Significant genes (FDR < 0.05): 0
#   → No probes survive FDR correction.
#   → With n/m = 32/22,011 ≈ 0.0015, this is a structural
#     consequence of the high-dimensional low-sample regime,
#     not a pipeline failure (see Section 10, Limitations).
#
# --------------------------------------------------
# Falling back to uncorrected p < 0.05 for exploratory analysis
# (explicitly flagged as exploratory throughout this study).
# --------------------------------------------------
#
# Significant genes (uncorrected p < 0.05): 1273
#
#   Upregulated in AD (higher expression):   320 genes
#   Downregulated in AD (lower expression):  953 genes
#
# === TOP 10 MOST SIGNIFICANT GENES (exploratory) ===
#  Gene_ID  log2_fold_change  p_value
#  2406420         -0.329521 0.000004
#  3634656         -0.424467 0.000005
#  2337217          0.250256 0.000077
#  2708855         -0.440508 0.000116
#  2958232          0.410112 0.000117
#  3139580         -0.185887 0.000124
#  2888284         -0.341652 0.000196
#  3624513          0.603654 0.000203
#  3820342         -0.174243 0.000205
#  3448744         -0.342785 0.000215
#
# Results saved to 'significant_genes_p005.csv'
#
# 1273 genes will be used for downstream GWAS integration.

# %% [markdown]
# # 13: Visualize Results - Volcano Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch

print("=== CREATING VOLCANO PLOT ===\n")

# Prepare data
log2fc = results_df['log2_fold_change']
neg_log_pval = -np.log10(results_df['p_value'])

# Count at both thresholds for legend accuracy
up_p05   = sum((results_df['p_value'] < 0.05)  & (results_df['log2_fold_change'] > 0))
down_p05 = sum((results_df['p_value'] < 0.05)  & (results_df['log2_fold_change'] < 0))
up_p001   = sum((results_df['p_value'] < 0.001) & (results_df['log2_fold_change'] > 0))
down_p001 = sum((results_df['p_value'] < 0.001) & (results_df['log2_fold_change'] < 0))

# Color points: use p < 0.05 as the coloring threshold (matches analysis)
colors = []
for i in range(len(results_df)):
    if results_df['p_value'].iloc[i] < 0.05:
        if results_df['log2_fold_change'].iloc[i] > 0:
            colors.append('red')
        else:
            colors.append('blue')
    else:
        colors.append('gray')

plt.figure(figsize=(10, 8))
plt.scatter(log2fc, neg_log_pval, c=colors, alpha=0.5, s=10)

# Two threshold lines — both shown for transparency
plt.axhline(y=-np.log10(0.05),  color='black',  linestyle='-.',
            linewidth=1, label='p = 0.05')
plt.axhline(y=-np.log10(0.001), color='black',  linestyle='--',
            linewidth=1, label='p = 0.001')

plt.xlabel(r'$\lg$FC (AD vs Control)', fontsize=12)
plt.ylabel(r'$-\lg_{10}$(p-value)', fontsize=12)
plt.title('Volcano Plot: Differential Expression in Alzheimer\'s Disease\n'
          f'(Analysis threshold: p < 0.05)', fontsize=14)

legend_elements = [
    Patch(facecolor='red',  label=f'Upregulated at p<0.05 ({up_p05})'),
    Patch(facecolor='blue', label=f'Downregulated at p<0.05 ({down_p05})'),
    Patch(facecolor='gray', label='Not significant'),
]
plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.savefig('volcano_plot_p005.png', dpi=300)
plt.show()

print(f"Volcano plot saved as 'volcano_plot_p005.png'")
print(f"\nAt p < 0.05:  {up_p05} up, {down_p05} down")
print(f"At p < 0.001: {up_p001} up, {down_p001} down")
# Out:
# === CREATING VOLCANO PLOT ===
# Volcano plot saved as 'volcano_plot_p005.png'
#
# At p < 0.05:  320 up, 953 down
# At p < 0.001: 6 up, 20 down

# %% [markdown]
# # 14: Download Gene Annotation File

# %%
# We need to map probe IDs to gene names
# Download the human gene annotation file from Ensembl

print("=== DOWNLOADING GENE ANNOTATION ===\n")
print("Downloading human gene coordinates from Ensembl...")

import pandas as pd

# URL for human gene annotation (GRCh38, release 109)
annotation_url = "https://ftp.ensembl.org/pub/release-109/gtf/homo_sapiens/Homo_sapiens.GRCh38.109.gtf.gz"

# Define column names for GTF format
annot_cols = ['seqname', 'source', 'feature', 'start', 'end', 
              'score', 'strand', 'frame', 'attribute']

# Load the annotation file
annotation_df = pd.read_csv(annotation_url, compression='gzip', sep='\t', 
                            comment='#', low_memory=False, names=annot_cols)

# Filter for only 'gene' features
gene_annotation_df = annotation_df[annotation_df['feature'] == 'gene'].copy()

# Extract gene name and gene ID from the attribute column
gene_annotation_df['gene_name'] = gene_annotation_df['attribute'].str.extract('gene_name "([^"]+)"')
gene_annotation_df['gene_id'] = gene_annotation_df['attribute'].str.extract('gene_id "([^"]+)"')

# Keep only essential columns
gene_annotation_df = gene_annotation_df[['seqname', 'start', 'end', 'gene_name', 'gene_id']]
gene_annotation_df = gene_annotation_df.rename(columns={'seqname': 'chromosome'})

print("Gene annotation file loaded successfully")
print(f"Number of genes in annotation: {len(gene_annotation_df)}")
gene_annotation_df.head()
# Out:
# === DOWNLOADING GENE ANNOTATION ===
#
# Downloading human gene coordinates from Ensembl...
# Gene annotation file loaded successfully
# Number of genes in annotation: 62710
#     chromosome    start      end gene_name          gene_id
# 0            1  1471765  1497848    ATAD3B  ENSG00000160072
# 107          1   182696   184174  DDX11L17  ENSG00000279928
# 114          1  2581560  2584533       NaN  ENSG00000228037
# 119          1  3069168  3438621    PRDM16  ENSG00000142611
# 339          1  5301928  5307394       NaN  ENSG00000284616

# %% [markdown]
# # 15: Map GWAS Variants to Nearest Genes

# %%
# Map each significant GWAS variant to its nearest gene
# This tells us which genes are genetically associated with AD

print("=== MAPPING GWAS VARIANTS TO GENES ===\n")

def find_nearest_gene(variant_chr, variant_pos, gene_annotation_df, max_distance=50000):
    """
    Find the nearest gene to a genomic variant.
    max_distance: only consider genes within this distance (default 50kb)
    """
    # Convert chromosome to string for matching
    chr_str = str(variant_chr)
    
    # Filter for same chromosome and genes with names
    chr_genes = gene_annotation_df[
        (gene_annotation_df['chromosome'] == chr_str) & 
        (gene_annotation_df['gene_name'].notna())
    ].copy()
    
    if chr_genes.empty:
        return None, None
    
    # Calculate distance to each gene
    chr_genes['distance'] = chr_genes.apply(
        lambda row: min(abs(row['start'] - variant_pos), 
                       abs(row['end'] - variant_pos)),
        axis=1
    )
    
    # Find nearest gene within max_distance
    nearby_genes = chr_genes[chr_genes['distance'] <= max_distance]
    
    if nearby_genes.empty:
        return None, None
    
    nearest = nearby_genes.nsmallest(1, 'distance')
    return nearest['gene_name'].iloc[0], nearest['distance'].iloc[0]

# Apply to all significant GWAS variants
print("Mapping GWAS variants to nearest genes (within 50kb)...")

gwas_significant_df[['nearest_gene', 'distance_to_gene']] = gwas_significant_df.apply(
    lambda row: pd.Series(find_nearest_gene(row['CHR'], row['BP'], gene_annotation_df)),
    axis=1
)

# Count results
mapped_count = gwas_significant_df['nearest_gene'].notna().sum()
print(f"GWAS variants mapped to genes: {mapped_count} out of {len(gwas_significant_df)}")

# Get unique genes from GWAS
gwas_genes = gwas_significant_df['nearest_gene'].dropna().unique()
print(f"Unique genes from GWAS analysis: {len(gwas_genes)}")

# Show first 10 genes
print(f"\nFirst 10 GWAS-associated genes:")
print(list(gwas_genes)[:10])
# Out:
# === MAPPING GWAS VARIANTS TO GENES ===
#
# Mapping GWAS variants to nearest genes (within 50kb)...
# GWAS variants mapped to genes: 2299 out of 2394
# Unique genes from GWAS analysis: 128
#
# First 10 GWAS-associated genes:
# ['UFC1', 'CD46P1', 'CDCA4P3', 'RNA5SP534', 'CR1L', 'CD46', 'MIR29B2CHG', 'MIR29B2', 'Y_RNA', 'ZFP91P1']

# %% [markdown]
# #  16: Upload Platform Annotation for Probe Mapping

# %%
# We need the GPL5175 platform file to map probe IDs to gene symbols
# You should have downloaded this file earlier

import os

print("=== LOADING PLATFORM ANNOTATION ===\n")

# Check if file exists
platform_file = "GPL5175-3188.txt"

# If you have a different filename, update it here
possible_files = [f for f in os.listdir('.') if 'GPL5175' in f]

if possible_files:
    platform_file = possible_files[0]
    print(f"Found platform file: {platform_file}")
else:
    print("ERROR: Platform annotation file not found!")
    print("Please download GPL5175 annotation from:")
    print("https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GPL5175")
    print("\nLook for 'Download full table' option")
# Out:
# === LOADING PLATFORM ANNOTATION ===
#
# Found platform file: GPL5175-3188.txt

# %% [markdown]
# # 17: Process Platform Annotation File

# %%
# Process the GPL5175 platform file to map probe IDs to gene symbols

print("=== PROCESSING PLATFORM ANNOTATION ===\n")

platform_file = "GPL5175-3188.txt"

# File structure
print("Examining file structure...")

with open(platform_file, 'r', encoding='utf-8', errors='ignore') as f:
    lines = f.readlines()

# Find where the actual data table starts (look for header with ID)
data_start = None
for i, line in enumerate(lines):
    # Skip comment lines and find the header
    if line.startswith('#'):
        continue
    # Check if this looks like a header line
    if 'ID' in line and '\t' in line:
        data_start = i
        print(f"Header found at line {i}: {line[:100]}...")
        break

if data_start is None:
    # Try another approach - find line with multiple tabs
    for i, line in enumerate(lines):
        if line.count('\t') >= 5:
            data_start = i
            print(f"Data starts at line {i}")
            break

# Read with error handling
try:
    platform_df = pd.read_csv(platform_file, sep='\t', skiprows=data_start, 
                              low_memory=False, on_bad_lines='skip')
    print(f"Platform file loaded: {platform_df.shape[0]} rows, {platform_df.shape[1]} columns")
    print(f"\nColumns found: {platform_df.columns.tolist()}")
except Exception as e:
    print(f"Error reading file: {e}")
    print("\nTrying alternative approach...")
    
    # Manual parsing
    platform_df = pd.read_csv(platform_file, sep='\t', skiprows=data_start,
                              low_memory=False, error_bad_lines=False, 
                              warn_bad_lines=False)
    print(f"Platform file loaded: {platform_df.shape[0]} rows")
# Out:
# === PROCESSING PLATFORM ANNOTATION ===
#
# Examining file structure...
# Header found at line 12: ID	GB_LIST	SPOT_ID	seqname	RANGE_GB	RANGE_STRAND	RANGE_START	RANGE_STOP	total_probes	gene_assignment...
# Platform file loaded: 316919 rows, 12 columns
#
# Columns found: ['ID', 'GB_LIST', 'SPOT_ID', 'seqname', 'RANGE_GB', 'RANGE_STRAND', 'RANGE_START', 'RANGE_STOP', 'total_probes', 'gene_assignment', 'mrna_assignment', 'category']

# %% [markdown]
# # 18: Create Probe-to-Gene Mapping

# %%
# The gene_assignment column has a complex format
# Examine it and extract the actual gene symbols

print("=== CREATING PROBE-TO-GENE MAPPING ===\n")

print("\n" + "="*50)
print("Extracting gene symbols from gene_assignment...")
print("="*50 + "\n")

# Create mapping dictionary
probe_to_gene = {}

for _, row in platform_df.iterrows():
    try:
        probe_id = str(row['ID']).strip()
        gene_info = str(row['gene_assignment']).strip()
        
        # Skip empty or invalid entries
        if gene_info in ['nan', 'NaN', '---', '', 'NULL', 'None']:
            continue
        
        # The gene_assignment format is usually:
        # "accession // gene_symbol // description // chromosome // ..."
        # We need to extract the gene symbol (usually second field after //)
        
        if '//' in gene_info:
            parts = [p.strip() for p in gene_info.split('//')]
            
            # Try to find the gene symbol
            # It's usually the second part, and looks like a gene name (short, alphanumeric)
            gene_symbol = None
            
            for part in parts[1:4]:  # Check parts 2, 3, 4
                # Gene symbols are typically short and contain letters
                if part and 2 <= len(part) <= 20:
                    # Skip if it looks like an accession number
                    if part.startswith(('NM_', 'NR_', 'XM_', 'XR_', 'BC', 'AK', 'ENST')):
                        continue
                    # Skip if it's all numbers
                    if part.isdigit():
                        continue
                    # This looks like a gene symbol
                    gene_symbol = part.upper()
                    break
            
            if gene_symbol:
                probe_to_gene[probe_id] = gene_symbol
                
    except Exception as e:
        continue

print(f"Successfully mapped {len(probe_to_gene)} probes to gene symbols")

# Show examples
if probe_to_gene:
    print("\nFirst 15 mappings:")
    for i, (probe, gene) in enumerate(list(probe_to_gene.items())[:15]):
        print(f"  {probe} → {gene}")
else:
    print("WARNING: No mappings created!")
# Out:
# === CREATING PROBE-TO-GENE MAPPING ===
#
#
# ==================================================
# Extracting gene symbols from gene_assignment...
# ==================================================
#
# Successfully mapped 33475 probes to gene symbols
#
# First 15 mappings:
#   2315100 → DDX11L2
#   2315125 → OR4F17
#   2315147 → LOC100288692
#   2315160 → FLJ45445
#   2315163 → LOC100132062
#   2315191 → LOC100507658
#   2315218 → LOC100132062
#   2315224 → COX1
#   2315233 → FLJ45340
#   2315251 → OR4F16
#   2315301 → ND2
#   2315315 → COX2
#   2315334 → LOC100288692
#   2315348 → FLJ45445
#   2315373 → FAM87A

# %% [markdown]
# # 19: Map Significant DEGs to Gene Symbols

# %%
# Map our significant probe IDs to gene symbols

print("=== MAPPING SIGNIFICANT GENES ===\n")

# Get the significant probe IDs
significant_probe_ids = significant_genes['Gene_ID'].astype(str).tolist()
print(f"Number of significant probes to map: {len(significant_probe_ids)}")

# Map probes to gene symbols
mapped_genes = []
unmapped_probes = []

for probe_id in significant_probe_ids:
    gene_symbol = probe_to_gene.get(probe_id)
    if gene_symbol:
        mapped_genes.append(gene_symbol)
    else:
        unmapped_probes.append(probe_id)
        mapped_genes.append(None)

# Add gene symbols to significant genes dataframe
significant_genes_mapped = significant_genes.copy()
significant_genes_mapped['Gene_Symbol'] = mapped_genes

# Remove unmapped genes
significant_genes_mapped = significant_genes_mapped[significant_genes_mapped['Gene_Symbol'].notna()]

print(f"Successfully mapped: {len(significant_genes_mapped)} genes")
print(f"Could not map: {len(unmapped_probes)} probes")

# Get unique gene symbols
deg_gene_symbols = significant_genes_mapped['Gene_Symbol'].unique().tolist()
print(f"\nUnique DEG gene symbols: {len(deg_gene_symbols)}")

# Show top mapped genes
print("\nTop 10 Differentially Expressed Genes:")
print(significant_genes_mapped[['Gene_ID', 'Gene_Symbol', 'log2_fold_change', 'p_value']].head(10).to_string(index=False))
# Out:
# === MAPPING SIGNIFICANT GENES ===
#
# Number of significant probes to map: 1273
# Successfully mapped: 1070 genes
# Could not map: 203 probes
#
# Unique DEG gene symbols: 1068
#
# Top 10 Differentially Expressed Genes:
#  Gene_ID Gene_Symbol  log2_fold_change  p_value
#  2406420       CLSPN         -0.329521 0.000004
#  3634656      CHRNA3         -0.424467 0.000005
#  2337217    C1ORF175          0.250256 0.000077
#  2708855        LIPH         -0.440508 0.000116
#  2958232     COL21A1          0.410112 0.000117
#  3139580     SLCO5A1         -0.185887 0.000124
#  2888284       NOP16         -0.341652 0.000196
#  3624513       MYO5C          0.603654 0.000203
#  3820342        PPAN         -0.174243 0.000205
#  3448744       PTHLH         -0.342785 0.000215

# %% [markdown]
# # 20: Find the Multi-Omics Overlap

# %%
#Find genes that are BOTH in GWAS AND differentially expressed!

print("=" * 50)
print("**** MULTI-OMICS INTEGRATION ****")
print("=" * 50)

# Get gene lists
gwas_gene_set = set(gwas_genes)  # Genes near significant GWAS variants
deg_gene_set = set(deg_gene_symbols)  # Differentially expressed genes

print(f"\nGWAS-associated genes: {len(gwas_gene_set)}")
print(f"Differentially expressed genes: {len(deg_gene_set)}")

# Find the overlap
overlap_genes = gwas_gene_set & deg_gene_set

print(f"\n{'=' * 50}")
print(f"OVERLAP: {len(overlap_genes)} genes")
print(f"{'=' * 50}")

if overlap_genes:
    print("\nHigh-confidence candidate genes for Alzheimer's Disease:")
    print("(Both genetically associated AND functionally dysregulated)")
    print()
    for gene in sorted(overlap_genes):
        # Get expression info
        gene_info = significant_genes_mapped[significant_genes_mapped['Gene_Symbol'] == gene]
        if not gene_info.empty:
            fc = gene_info['log2_fold_change'].iloc[0]
            direction = "↑ Upregulated" if fc > 0 else "↓ Downregulated"
            print(f"{gene}: {direction} (log2FC = {fc:.3f})")
else:
    print("\nNo overlap found between GWAS genes and DEGs.")
    print("This is still a valid scientific result!")
    print("\nPossible reasons:")
    print("- Genetic variants may affect genes not captured by microarray")
    print("- Expression changes may occur in specific cell types")
    print("- Small sample size limits detection power")

# Save results
overlap_df = significant_genes_mapped[significant_genes_mapped['Gene_Symbol'].isin(overlap_genes)]
overlap_df.to_csv('multi_omics_overlap_genes.csv', index=False)
print(f"\nResults saved to 'multi_omics_overlap_genes.csv'")
# Out:
# ==================================================
# **** MULTI-OMICS INTEGRATION ****
# ==================================================
#
# GWAS-associated genes: 128
# Differentially expressed genes: 1068
#
# ==================================================
# OVERLAP: 8 genes
# ==================================================
#
# High-confidence candidate genes for Alzheimer's Disease:
# (Both genetically associated AND functionally dysregulated)
#
# ERCC2: ↓ Downregulated (log2FC = -0.151)
# FOSB: ↓ Downregulated (log2FC = -0.439)
# OPA3: ↓ Downregulated (log2FC = -0.107)
# QPCTL: ↓ Downregulated (log2FC = -0.147)
# RELB: ↓ Downregulated (log2FC = -0.204)
# RTN2: ↓ Downregulated (log2FC = -0.173)
# SNRPD2: ↓ Downregulated (log2FC = -0.236)
# TMEM126A: ↓ Downregulated (log2FC = -0.375)
#
# Results saved to 'multi_omics_overlap_genes.csv'

# %% [markdown]
# # 20a: hypergeometric test

# %%
from scipy.stats import hypergeom

print("=== HYPERGEOMETRIC TEST (Correct Background) ===\n")

# The correct background is NOT the whole genome (~20,000 genes).
# It's the set of genes that could ACTUALLY have been detected as a DEG —
# i.e., every unique gene symbol represented on the microarray platform.
testable_universe = set(probe_to_gene.values())
print(f"Testable universe (genes on the array): {len(testable_universe)}")

# Restrict GWAS genes to only those that were even testable on this platform
# (a GWAS gene not on the array could never have shown up as a DEG anyway)
gwas_in_universe = gwas_gene_set & testable_universe
deg_in_universe  = deg_gene_set & testable_universe  # should already ⊆ universe

M = len(testable_universe)        # population size
n = len(gwas_in_universe)         # GWAS genes within that population
N = len(deg_in_universe)          # DEG genes within that population
x = len(gwas_in_universe & deg_in_universe)  # observed overlap

print(f"\nGWAS genes in testable universe:  {n}")
print(f"DEG genes in testable universe:   {N}")
print(f"Observed overlap:                 {x}")

# P(overlap >= x) under the hypergeometric distribution
p_value = hypergeom.sf(x - 1, M, n, N)
expected_overlap = n * N / M

print(f"\nExpected overlap by chance: {expected_overlap:.2f} genes")
print(f"Observed overlap:           {x} genes")
print(f"Hypergeometric p-value:     {p_value:.4f}")

if p_value < 0.05:
    print("\n✓ Overlap is statistically significant under this test.")
else:
    print("\n  Overlap does NOT reach significance under this test either.")
# Out:
# === HYPERGEOMETRIC TEST (Correct Background) ===
#
# Testable universe (genes on the array): 22246
#
# GWAS genes in testable universe:  84
# DEG genes in testable universe:   1068
# Observed overlap:                 8
#
# Expected overlap by chance: 4.03 genes
# Observed overlap:           8 genes
# Hypergeometric p-value:     0.0484
#
# ✓ Overlap is statistically significant under this test.

# %% [markdown]
# # 20b: LD/APOE clustering check

# %%
print("=== CHECKING FOR LD-CLUSTERED CANDIDATES ===\n")

candidate_list = sorted(overlap_genes)  # your 8 (or 7) candidate genes

# Pull genomic position for each candidate from the annotation table
positions = []
for gene in candidate_list:
    row = gene_annotation_df[gene_annotation_df['gene_name'] == gene]
    if not row.empty:
        chrom = row['chromosome'].iloc[0]
        start = row['start'].iloc[0]
        positions.append((gene, chrom, start))
    else:
        positions.append((gene, None, None))

# Print raw positions
print(f"{'Gene':<12} {'Chr':<6} {'Start':<12}")
print("-" * 32)
for gene, chrom, start in positions:
    print(f"{gene:<12} {str(chrom):<6} {str(start):<12}")

# Group genes that are on the same chromosome and within 1 Mb of each other
# (1 Mb is a generous, commonly-used proxy for "same LD block" without
#  needing a full LD reference panel)
window = 1_000_000  # 1 Mb
positions_valid = [(g, c, s) for g, c, s in positions if c is not None]
positions_valid.sort(key=lambda x: (x[1], x[2]))

clusters = []
current_cluster = []

for gene, chrom, start in positions_valid:
    if not current_cluster:
        current_cluster = [(gene, chrom, start)]
    else:
        last_gene, last_chrom, last_start = current_cluster[-1]
        if chrom == last_chrom and abs(start - last_start) <= window:
            current_cluster.append((gene, chrom, start))
        else:
            clusters.append(current_cluster)
            current_cluster = [(gene, chrom, start)]
if current_cluster:
    clusters.append(current_cluster)

print(f"\n{'='*50}")
print("CLUSTER SUMMARY")
print(f"{'='*50}")
independent_signal_count = 0
for i, cluster in enumerate(clusters, 1):
    genes_in_cluster = [g for g, c, s in cluster]
    if len(cluster) > 1:
        print(f"Cluster {i} (chr{cluster[0][1]}, likely same LD block): {genes_in_cluster}")
    else:
        print(f"Cluster {i} (chr{cluster[0][1]}, independent signal): {genes_in_cluster}")
    independent_signal_count += 1

print(f"\nTotal candidate genes:        {len(candidate_list)}")
print(f"Estimated independent loci:   {independent_signal_count}")
# Out:
# === CHECKING FOR LD-CLUSTERED CANDIDATES ===
#
# Gene         Chr    Start
# --------------------------------
# ERCC2        19     45349837
# FOSB         19     45467995
# OPA3         19     45527767
# QPCTL        19     45692403
# RELB         19     45001461
# RTN2         19     45485294
# SNRPD2       19     45687460
# TMEM126A     11     85647967
#
# ==================================================
# CLUSTER SUMMARY
# ==================================================
# Cluster 1 (chr11, independent signal): ['TMEM126A']
# Cluster 2 (chr19, likely same LD block): ['RELB', 'ERCC2', 'FOSB', 'RTN2', 'OPA3', 'SNRPD2', 'QPCTL']
#
# Total candidate genes:        8
# Estimated independent loci:   2

# %% [markdown]
# # 20c: GWAS Mapping Window Sensitivity Analysis

# %%
# Re-runs SNP-to-gene mapping at 20kb, 50kb, 100kb, 200kb
# to test how stable the 8 candidate genes are to this parameter choice

import time

print("=== MAPPING WINDOW SENSITIVITY ANALYSIS ===\n")
print("Testing windows: 20kb, 50kb, 100kb, 200kb")
print("(This reruns SNP-to-gene mapping 4 times)\n")

windows_kb = [20, 50, 100, 200]
window_results = {}

original_8 = ['ERCC2', 'FOSB', 'OPA3', 'QPCTL', 'RELB', 'RTN2', 'SNRPD2', 'TMEM126A']

for w_kb in windows_kb:
    w_bp = w_kb * 1000
    print(f"--- Running window = {w_kb}kb ---")
    start_time = time.time()

    # Re-map every significant SNP at this window size
    mapped = gwas_significant_df.apply(
        lambda row: pd.Series(
            find_nearest_gene(row['CHR'], row['BP'], gene_annotation_df, max_distance=w_bp)
        ),
        axis=1
    )
    nearest_genes_w = mapped[0].dropna().unique()
    gwas_set_w = set(nearest_genes_w)

    # Overlap with the SAME DEG list used throughout (deg_gene_set stays fixed)
    overlap_w = gwas_set_w & deg_gene_set

    elapsed = time.time() - start_time
    window_results[w_kb] = {
        'n_gwas_genes': len(gwas_set_w),
        'overlap': overlap_w,
        'n_overlap': len(overlap_w)
    }

    print(f"  GWAS genes mapped: {len(gwas_set_w)}")
    print(f"  Overlap with DEGs: {len(overlap_w)} genes")
    print(f"  Time: {elapsed:.1f}s\n")

# Summary table
print(f"{'='*60}")
print("SUMMARY: Overlap gene count by window size")
print(f"{'='*60}")
print(f"{'Window':<10} {'GWAS genes':<12} {'Overlap count':<15} {'Genes'}")
print("-" * 60)
for w_kb in windows_kb:
    r = window_results[w_kb]
    genes_str = ', '.join(sorted(r['overlap']))
    print(f"{w_kb}kb{'':<7} {r['n_gwas_genes']:<12} {r['n_overlap']:<15} {genes_str}")

# Check which of the original 8 genes survive at each window
print(f"\n{'='*60}")
print("STABILITY OF ORIGINAL 8 CANDIDATES ACROSS WINDOWS")
print(f"{'='*60}")
print(f"{'Gene':<12}", end="")
for w_kb in windows_kb:
    print(f"{str(w_kb)+'kb':<10}", end="")
print()
print("-" * (12 + 10 * len(windows_kb)))

for gene in original_8:
    print(f"{gene:<12}", end="")
    for w_kb in windows_kb:
        present = "✓" if gene in window_results[w_kb]['overlap'] else "✗"
        print(f"{present:<10}", end="")
    print()

# How many of the 8 survive at ALL window sizes?
stable_genes = [
    g for g in original_8
    if all(g in window_results[w]['overlap'] for w in windows_kb)
]
print(f"\nGenes stable across ALL 4 window sizes: {len(stable_genes)}")
print(f"  {stable_genes}")
# Out:
# === MAPPING WINDOW SENSITIVITY ANALYSIS ===
#
# Testing windows: 20kb, 50kb, 100kb, 200kb
# (This reruns SNP-to-gene mapping 4 times)
#
# --- Running window = 20kb ---
#   GWAS genes mapped: 119
#   Overlap with DEGs: 8 genes
#   Time: 68.1s
#
# --- Running window = 50kb ---
#   GWAS genes mapped: 128
#   Overlap with DEGs: 8 genes
#   Time: 62.6s
#
# --- Running window = 100kb ---
#   GWAS genes mapped: 131
#   Overlap with DEGs: 8 genes
#   Time: 62.1s
#
# --- Running window = 200kb ---
#   GWAS genes mapped: 132
#   Overlap with DEGs: 8 genes
#   Time: 62.2s
#
# ============================================================
# SUMMARY: Overlap gene count by window size
# ============================================================
# Window     GWAS genes   Overlap count   Genes
# ------------------------------------------------------------
# 20kb        119          8               ERCC2, FOSB, OPA3, QPCTL, RELB, RTN2, SNRPD2, TMEM126A
# 50kb        128          8               ERCC2, FOSB, OPA3, QPCTL, RELB, RTN2, SNRPD2, TMEM126A
# 100kb        131          8               ERCC2, FOSB, OPA3, QPCTL, RELB, RTN2, SNRPD2, TMEM126A
# 200kb        132          8               ERCC2, FOSB, OPA3, QPCTL, RELB, RTN2, SNRPD2, TMEM126A
#
# ============================================================
# STABILITY OF ORIGINAL 8 CANDIDATES ACROSS WINDOWS
# ============================================================
# Gene        20kb      50kb      100kb     200kb
# ----------------------------------------------------
# ERCC2       ✓         ✓         ✓         ✓
# FOSB        ✓         ✓         ✓         ✓
# OPA3        ✓         ✓         ✓         ✓
# QPCTL       ✓         ✓         ✓         ✓
# RELB        ✓         ✓         ✓         ✓
# RTN2        ✓         ✓         ✓         ✓
# SNRPD2      ✓         ✓         ✓         ✓
# TMEM126A    ✓         ✓         ✓         ✓
#
# Genes stable across ALL 4 window sizes: 8
#   ['ERCC2', 'FOSB', 'OPA3', 'QPCTL', 'RELB', 'RTN2', 'SNRPD2', 'TMEM126A']

# %% [markdown]
# # 20d: Mann-Whitney U Robustness Check

# %%
# Non-parametric alternative to the t-test — does not assume normality,
# more appropriate for small sample sizes (13 vs 19).
# This is a SIDE CHECK: uses separate variable names (mw_*) so it does
# NOT overwrite results_df / significant_genes / deg_gene_set used
# throughout the rest of the pipeline.

from scipy import stats as mw_stats

print("=== ROBUSTNESS CHECK: MANN-WHITNEY U TEST ===\n")
print("Re-running differential expression with a non-parametric test")
print("to check whether the 8 candidate genes depend on the t-test's")
print("normality assumption.\n")

control_data_mw = geo_matrix_normalized[control_samples]
ad_data_mw      = geo_matrix_normalized[ad_samples]
gene_ids_mw     = geo_matrix_normalized['ID_REF']

mw_p_values = []

for idx in range(len(geo_matrix_normalized)):
    control_values = control_data_mw.iloc[idx].values
    ad_values      = ad_data_mw.iloc[idx].values

    _, p_val = mw_stats.mannwhitneyu(
        ad_values, control_values, alternative='two-sided'
    )
    mw_p_values.append(p_val)

mw_results_df = pd.DataFrame({
    'Gene_ID': gene_ids_mw,
    'log2_fold_change': true_log2_fc,  # same fold changes as primary analysis
    'mw_p_value': mw_p_values
})

print(f"Mann-Whitney tests complete for {len(mw_results_df)} genes.")
print(f"Genes with p < 0.05 (uncorrected): {sum(mw_results_df['mw_p_value'] < 0.05)}")

# Apply the same exploratory threshold used in the primary analysis
mw_significant = mw_results_df[mw_results_df['mw_p_value'] < 0.05].copy()

# Map significant probes to gene symbols using the SAME probe_to_gene dict
mw_significant_ids = mw_significant['Gene_ID'].astype(str).tolist()
mw_gene_symbols = [
    probe_to_gene.get(pid) for pid in mw_significant_ids
]
mw_significant['Gene_Symbol'] = mw_gene_symbols
mw_significant = mw_significant[mw_significant['Gene_Symbol'].notna()]

mw_deg_gene_set = set(mw_significant['Gene_Symbol'].unique().tolist())
print(f"Unique DEG gene symbols (Mann-Whitney): {len(mw_deg_gene_set)}")

# Overlap with the SAME GWAS gene set used throughout
mw_overlap = gwas_gene_set & mw_deg_gene_set

print(f"\n{'='*55}")
print(f"MANN-WHITNEY OVERLAP: {len(mw_overlap)} genes")
print(f"{'='*55}")

# Compare directly against the primary (t-test) 8 candidates
print(f"\n{'Gene':<12} {'In t-test set':<15} {'In Mann-Whitney set':<20}")
print("-" * 47)
for gene in sorted(overlap_genes):
    in_mw = "✓" if gene in mw_overlap else "✗"
    print(f"{gene:<12} {'✓':<15} {in_mw:<20}")

n_confirmed = len(overlap_genes & mw_overlap)
print(f"\n{n_confirmed} of {len(overlap_genes)} original candidates confirmed under Mann-Whitney U.")

not_confirmed = overlap_genes - mw_overlap
if not_confirmed:
    print(f"Not confirmed: {sorted(not_confirmed)}")
# Out:
# === ROBUSTNESS CHECK: MANN-WHITNEY U TEST ===
#
# Re-running differential expression with a non-parametric test
# to check whether the 8 candidate genes depend on the t-test's
# normality assumption.
#
# Mann-Whitney tests complete for 22011 genes.
# Genes with p < 0.05 (uncorrected): 1087
# Unique DEG gene symbols (Mann-Whitney): 931
#
# =======================================================
# MANN-WHITNEY OVERLAP: 7 genes
# =======================================================
#
# Gene         In t-test set   In Mann-Whitney set
# -----------------------------------------------
# ERCC2        ✓               ✓
# FOSB         ✓               ✓
# OPA3         ✓               ✓
# QPCTL        ✓               ✓
# RELB         ✓               ✗
# RTN2         ✓               ✓
# SNRPD2       ✓               ✓
# TMEM126A     ✓               ✓
#
# 7 of 8 original candidates confirmed under Mann-Whitney U.
# Not confirmed: ['RELB']

# %% [markdown]
# # 20e: Permutation Test

# %%
# Uses vectorized numpy operations instead of gene-by-gene loops

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

print("=== PERMUTATION TEST FOR GWAS OVERLAP (Fast Version) ===\n")
print("Running 1000 permutations using vectorized operations...\n")

np.random.seed(42)  # for exact reproducibility

# Observed overlap
observed_overlap = len(overlap_genes)
print(f"Observed overlap (real result): {observed_overlap} genes\n")

# Prepare data matrix once — shape: (22011 probes, 32 samples)
all_samples_used = control_samples + ad_samples
n_control        = len(control_samples)
n_ad             = len(ad_samples)
n_total          = n_control + n_ad
n_permutations   = 1000

# Extract the data matrix for the 32 selected samples only
data_matrix = geo_matrix_normalized[all_samples_used].values  # shape: (22011, 32)

# Pre-compute GWAS gene set
gwas_set = set(gwas_genes)

permuted_overlaps = []

for perm in range(n_permutations):
    # Shuffle sample indices
    shuffled_idx  = np.random.permutation(n_total)
    ctrl_idx      = shuffled_idx[:n_control]
    ad_idx        = shuffled_idx[n_control:]

    ctrl_data = data_matrix[:, ctrl_idx]   # shape: (22011, 13)
    ad_data   = data_matrix[:, ad_idx]     # shape: (22011, 19)

    # Vectorized t-test across all probes at once
    _, p_vals = stats.ttest_ind(ad_data, ctrl_data, axis=1)

    # Get significant probe indices
    sig_mask     = p_vals < 0.05
    sig_probe_ids = geo_matrix_normalized['ID_REF'].values[sig_mask].astype(str)

    # Map to gene symbols
    perm_genes = set(
        probe_to_gene[pid]
        for pid in sig_probe_ids
        if pid in probe_to_gene
    )

    # Count overlap with GWAS
    perm_overlap = len(gwas_set & perm_genes)
    permuted_overlaps.append(perm_overlap)

    if (perm + 1) % 100 == 0:
        print(f"  Completed {perm + 1} / {n_permutations} permutations...")

# Calculate empirical p-value
empirical_p = sum(
    o >= observed_overlap for o in permuted_overlaps
) / n_permutations

print(f"\n{'='*50}")
print(f"PERMUTATION TEST RESULTS")
print(f"{'='*50}")
print(f"Observed overlap:               {observed_overlap} genes")
print(f"Mean permuted overlap:          {np.mean(permuted_overlaps):.2f} genes")
print(f"Max permuted overlap:           {max(permuted_overlaps)} genes")
print(f"Permutations >= {observed_overlap} genes:       "
      f"{sum(o >= observed_overlap for o in permuted_overlaps)} / {n_permutations}")
print(f"Empirical p-value:              {empirical_p:.4f}")

if empirical_p < 0.05:
    print(f"\n✓ The overlap is statistically significant "
          f"(empirical p = {empirical_p:.4f})")
    print("  This result is unlikely to occur by random chance.")
else:
    print(f"\n  The overlap does not reach empirical significance "
          f"(p = {empirical_p:.4f})")

# Plot
plt.figure(figsize=(10, 6))
plt.hist(permuted_overlaps,
         bins=range(0, max(permuted_overlaps) + 2),
         color='steelblue', edgecolor='black', alpha=0.7)
plt.axvline(x=observed_overlap, color='red', linewidth=2,
            linestyle='--',
            label=f'Observed overlap = {observed_overlap}')
plt.xlabel('Number of GWAS Overlap Genes (permuted)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title(
    'Permutation Test: Is the GWAS Overlap Statistically Significant?\n'
    f'(Empirical p = {empirical_p:.4f}, 1,000 permutations)',
    fontsize=13
)
plt.legend(fontsize=11)
plt.tight_layout()
plt.savefig('permutation_test.png', dpi=150)
plt.show()

print("\nPlot saved as 'permutation_test.png'")
# Out:
# === PERMUTATION TEST FOR GWAS OVERLAP (Fast Version) ===
#
# Running 1000 permutations using vectorized operations...
#
# Observed overlap (real result): 8 genes
#
#   Completed 100 / 1000 permutations...
#   Completed 200 / 1000 permutations...
#   Completed 300 / 1000 permutations...
#   Completed 400 / 1000 permutations...
#   Completed 500 / 1000 permutations...
#   Completed 600 / 1000 permutations...
#   Completed 700 / 1000 permutations...
#   Completed 800 / 1000 permutations...
#   Completed 900 / 1000 permutations...
#   Completed 1000 / 1000 permutations...
#
# ==================================================
# PERMUTATION TEST RESULTS
# ==================================================
# Observed overlap:               8 genes
# Mean permuted overlap:          4.05 genes
# Max permuted overlap:           32 genes
# Permutations >= 8 genes:       143 / 1000
# Empirical p-value:              0.1430
#
#   The overlap does not reach empirical significance (p = 0.1430)
# Plot saved as 'permutation_test.png'

# %% [markdown]
# # 21: Functional enrichment analysis for DEGs (GO + KEGG)

# %%
# 21: Functional Enrichment Analysis for DEGs (GO + KEGG)
import gseapy as gp
import pandas as pd
import re

print("=== FUNCTIONAL ENRICHMENT ANALYSIS ===\n")

# Step 1: Filter out invalid gene symbols from the 1068 DEG list
def is_valid_gene_symbol(gene):
    if pd.isna(gene) or str(gene).strip() == '':
        return False
    gene_str = str(gene).strip()
    if re.match(r'^\d+[PQpq]\d+', gene_str):   # chromosomal locations
        return False
    if re.match(r'^\d+[PQpq]\d+\|', gene_str): # piped chromosomal locations
        return False
    if '|' in gene_str:                          # ambiguous dual-gene entries
        return False
    if len(gene_str) > 20:                       # likely a description
        return False
    if re.match(r'^LOC\d+$', gene_str):          # predicted loci
        return False
    return True

deg_genes_raw   = sorted(set(deg_gene_symbols))
deg_genes_clean = [g for g in deg_genes_raw if is_valid_gene_symbol(g)]
removed         = set(deg_genes_raw) - set(deg_genes_clean)

print(f"Gene list summary:")
print(f"  Before filtering: {len(deg_genes_raw)}")
print(f"  After filtering:  {len(deg_genes_clean)}")
print(f"  Removed ({len(removed)}): {', '.join(sorted(removed))}\n")

if len(deg_genes_clean) == 0:
    raise ValueError("No valid genes remaining after filtering.")

# Step 2: Run Enrichr on cleaned list
print("Running Enrichr (GO Biological Process 2023 + KEGG 2021 Human)...")

enr = gp.enrichr(
    gene_list=deg_genes_clean,
    gene_sets=['GO_Biological_Process_2023', 'KEGG_2021_Human'],
    organism='Human',
    cutoff=0.05,
    outdir='enrichment_results',
    no_plot=True
)

enrich_df = enr.results
print(f"\nTotal terms returned: {enrich_df.shape[0]}")

# Step 3: Show top 10 by adjusted p-value
print("\nTop 10 enriched terms:")
display(enrich_df[['Gene_set', 'Term', 'Overlap', 'Adjusted P-value']].head(10))

# Step 4: Check how many pass adjusted p < 0.05
sig_terms = enrich_df[enrich_df['Adjusted P-value'] < 0.05]
print(f"\nTerms significant at adjusted p < 0.05: {len(sig_terms)}")
if len(sig_terms) > 0:
    display(sig_terms[['Gene_set', 'Term', 'Overlap', 'Adjusted P-value']])
# Out:
# === FUNCTIONAL ENRICHMENT ANALYSIS ===
#
# Gene list summary:
#   Before filtering: 1068
#   After filtering:  1061
#   Removed (7): 14Q32.2, 16Q23.2, 19Q13.33, 22Q11|22Q11.23, LOC100131492, LOC100131943, LOC440173
#
# Running Enrichr (GO Biological Process 2023 + KEGG 2021 Human)...
#
# Total terms returned: 3431
#
# Top 10 enriched terms:
#                      Gene_set  \
# 0  GO_Biological_Process_2023
# 1  GO_Biological_Process_2023
# 2  GO_Biological_Process_2023
# 3  GO_Biological_Process_2023
# 4  GO_Biological_Process_2023
# 5  GO_Biological_Process_2023
# 6  GO_Biological_Process_2023
# 7  GO_Biological_Process_2023
# 8  GO_Biological_Process_2023
# 9  GO_Biological_Process_2023
#
#                                                 Term Overlap  Adjusted P-value
# 0                  Cellular Respiration (GO:0045333)   13/85          0.453506
# 1  Glycosaminoglycan Biosynthetic Process (GO:000...   10/58          0.453506
# 2  Regulation Of NMDA Receptor Activity (GO:2000310)    5/16          0.453506
# 3     Proteoglycan Biosynthetic Process (GO:0030166)    7/32          0.453506
# 4        Cerebral Cortex Cell Migration (GO:0021795)     3/5          0.453506
# 5  Regulation Of Neurotransmitter Receptor Activi...    8/42          0.453506
# 6                      DNA Modification (GO:0006304)    5/17          0.453506
# 7              Monoatomic Ion Transport (GO:0006811)  14/107          0.453506
# 8  Energy Derivation By Oxidation Of Organic Comp...    8/43          0.453506
# 9   NADH Dehydrogenase Complex Assembly (GO:0010257)    9/53          0.453506
# Terms significant at adjusted p < 0.05: 1
#              Gene_set                            Term Overlap  \
# 3136  KEGG_2021_Human  Glycosaminoglycan biosynthesis   11/53
#
#       Adjusted P-value
# 3136          0.025607

# %% [markdown]
# # 21b: Functional Enrichment on the 8 Candidate Genes Only

# %%
# (separate from the full 1,068-gene DEG enrichment in cell 21)

import gseapy as gp

print("=== FUNCTIONAL ENRICHMENT — 8 CANDIDATE GENES ONLY ===\n")

candidate_genes_list = sorted(overlap_genes)
print(f"Candidate gene set ({len(candidate_genes_list)} genes): {candidate_genes_list}\n")

print("Running Enrichr (GO Biological Process 2023 + KEGG 2021 Human)...")

try:
    enr_candidates = gp.enrichr(
        gene_list=candidate_genes_list,
        gene_sets=['GO_Biological_Process_2023', 'KEGG_2021_Human'],
        organism='Human',
        cutoff=0.05,
        outdir='enrichment_results_candidates_only',
        no_plot=True
    )

    candidates_enrich_df = enr_candidates.results
    print(f"\nTotal terms returned: {candidates_enrich_df.shape[0]}")

    if candidates_enrich_df.shape[0] > 0:
        print("\nTop 10 terms (by adjusted p-value):")
        display(candidates_enrich_df[['Gene_set', 'Term', 'Overlap', 'Adjusted P-value']].head(10))

        sig_candidates = candidates_enrich_df[candidates_enrich_df['Adjusted P-value'] < 0.05]
        print(f"\nTerms significant at adjusted p < 0.05: {len(sig_candidates)}")
        if len(sig_candidates) > 0:
            display(sig_candidates[['Gene_set', 'Term', 'Overlap', 'Adjusted P-value']])
        else:
            print("No terms reached significance — expected, given the small (n=8) input size.")
    else:
        print("Enrichr returned no terms for this gene list.")

except Exception as e:
    print(f"Enrichr call failed: {e}")
    print("This can happen with very small gene lists — some databases require a minimum overlap.")
# Out:
# === FUNCTIONAL ENRICHMENT — 8 CANDIDATE GENES ONLY ===
#
# Candidate gene set (8 genes): ['ERCC2', 'FOSB', 'OPA3', 'QPCTL', 'RELB', 'RTN2', 'SNRPD2', 'TMEM126A']
#
# Running Enrichr (GO Biological Process 2023 + KEGG 2021 Human)...
#
# Total terms returned: 68
#
# Top 10 terms (by adjusted p-value):
#                      Gene_set  \
# 0  GO_Biological_Process_2023
# 1  GO_Biological_Process_2023
# 2  GO_Biological_Process_2023
# 3  GO_Biological_Process_2023
# 4  GO_Biological_Process_2023
# 5  GO_Biological_Process_2023
# 6  GO_Biological_Process_2023
# 7  GO_Biological_Process_2023
# 8  GO_Biological_Process_2023
# 9  GO_Biological_Process_2023
#
#                                                 Term Overlap  Adjusted P-value
# 0  7-Methylguanosine Cap Hypermethylation (GO:003...     1/7          0.046931
# 1                           RNA Capping (GO:0036260)     1/7          0.046931
# 2             Hair Cell Differentiation (GO:0035315)     1/7          0.046931
# 3  Negative Regulation Of Interferon-Beta Product...    1/10          0.046931
# 4             Cranial Nerve Development (GO:0021545)    1/13          0.046931
# 5  Negative Regulation Of Amyloid-Beta Formation ...    1/16          0.046931
# 6  Regulation Of Glucose Transmembrane Transport ...    1/17          0.046931
# 7  Negative Regulation Of Amyloid Precursor Prote...    1/18          0.046931
# 8       U2-type Prespliceosome Assembly (GO:1903241)    1/23          0.046931
# 9      Mononuclear Cell Differentiation (GO:1903131)    1/24          0.046931
# Terms significant at adjusted p < 0.05: 29
#                       Gene_set  \
# 0   GO_Biological_Process_2023
# 1   GO_Biological_Process_2023
# 2   GO_Biological_Process_2023
# 3   GO_Biological_Process_2023
# 4   GO_Biological_Process_2023
# 5   GO_Biological_Process_2023
# 6   GO_Biological_Process_2023
# 7   GO_Biological_Process_2023
# 8   GO_Biological_Process_2023
# 9   GO_Biological_Process_2023
# 10  GO_Biological_Process_2023
# 11  GO_Biological_Process_2023
# 12  GO_Biological_Process_2023
# 13  GO_Biological_Process_2023
# 14  GO_Biological_Process_2023
# 15  GO_Biological_Process_2023
# 16  GO_Biological_Process_2023
# 17  GO_Biological_Process_2023
# 18  GO_Biological_Process_2023
# 19  GO_Biological_Process_2023
# 20  GO_Biological_Process_2023
# 21  GO_Biological_Process_2023
# 22  GO_Biological_Process_2023
# 23  GO_Biological_Process_2023
# 24  GO_Biological_Process_2023
# 25  GO_Biological_Process_2023
# 26  GO_Biological_Process_2023
# 27  GO_Biological_Process_2023
# 55             KEGG_2021_Human
#
#                                                  Term Overlap  \
# 0   7-Methylguanosine Cap Hypermethylation (GO:003...     1/7
# 1                            RNA Capping (GO:0036260)     1/7
# 2              Hair Cell Differentiation (GO:0035315)     1/7
# 3   Negative Regulation Of Interferon-Beta Product...    1/10
# 4              Cranial Nerve Development (GO:0021545)    1/13
# 5   Negative Regulation Of Amyloid-Beta Formation ...    1/16
# 6   Regulation Of Glucose Transmembrane Transport ...    1/17
# 7   Negative Regulation Of Amyloid Precursor Prote...    1/18
# 8        U2-type Prespliceosome Assembly (GO:1903241)    1/23
# 9       Mononuclear Cell Differentiation (GO:1903131)    1/24
# 10  Regulation Of Cell Cycle Phase Transition (GO:...    1/25
# 11               NIK/NF-kappaB Signaling (GO:0038061)    1/32
# 12  Regulation Of Amyloid-Beta Formation (GO:1902003)    1/33
# 13          Regulation Of Glucose Import (GO:0046324)    1/36
# 14           Spliceosomal snRNP Assembly (GO:0000387)    1/37
# 15  Negative Regulation Of Type I Interferon Produ...    1/38
# 16  Regulation Of Primary Metabolic Process (GO:00...    1/43
# 17   I-kappaB kinase/NF-kappaB Signaling (GO:0007249)    1/45
# 18  Intracellular Protein Transmembrane Transport ...    1/46
# 19  Regulation Of Interferon-Beta Production (GO:0...    1/50
# 20  Positive Regulation Of DNA Recombination (GO:0...    1/51
# 21   NADH Dehydrogenase Complex Assembly (GO:0010257)    1/53
# 22  Mitochondrial Respiratory Chain Complex I Asse...    1/53
# 23        Epidermal Cell Differentiation (GO:0009913)    1/54
# 24  Regulation Of Lipid Metabolic Process (GO:0019...    1/54
# 25            Nucleotide-Excision Repair (GO:0006289)    1/56
# 26         Spliceosomal Complex Assembly (GO:0000245)    1/62
# 27                       RNA Methylation (GO:0001510)    1/62
# 55                         Osteoclast differentiation   2/127
#
#     Adjusted P-value
# 0           0.046931
# 1           0.046931
# 2           0.046931
# 3           0.046931
# 4           0.046931
# 5           0.046931
# 6           0.046931
# 7           0.046931
# 8           0.046931
# 9           0.046931
# 10          0.046931
# 11          0.046931
# 12          0.046931
# 13          0.046931
# 14          0.046931
# 15          0.046931
# 16          0.046931
# 17          0.046931
# 18          0.046931
# 19          0.046931
# 20          0.046931
# 21          0.046931
# 22          0.046931
# 23          0.046931
# 24          0.046931
# 25          0.046931
# 26          0.048197
# 27          0.048197
# 55          0.014202

# %% [markdown]
# # 22: Verify the 8 Candidate Genes Against Source Lists

# %%
print("=== VERIFYING 8 OVERLAP GENES ===\n")

overlap_genes_list = ['ERCC2', 'FOSB', 'OPA3', 'QPCTL', 'RELB', 'RTN2', 'SNRPD2', 'TMEM126A']

print("Gene | In GWAS list | In DEG list | p-value | log2FC")
print("-" * 65)
for gene in overlap_genes_list:
    in_gwas = gene in gwas_gene_set
    in_deg  = gene in deg_gene_set
    
    # Get expression stats
    gene_row = significant_genes_mapped[significant_genes_mapped['Gene_Symbol'] == gene]
    if not gene_row.empty:
        pval = gene_row['p_value'].iloc[0]
        fc   = gene_row['log2_fold_change'].iloc[0]
        print(f"{gene:<12} {str(in_gwas):<14} {str(in_deg):<13} {pval:.6f}  {fc:.3f}")
    else:
        print(f"{gene:<12} {str(in_gwas):<14} {str(in_deg):<13} NOT FOUND IN DEG TABLE")

print(f"\nExpected overlap count: 8")
print(f"Verified overlap count: {sum(g in gwas_gene_set and g in deg_gene_set for g in overlap_genes_list)}")
# Out:
# === VERIFYING 8 OVERLAP GENES ===
#
# Gene | In GWAS list | In DEG list | p-value | log2FC
# -----------------------------------------------------------------
# ERCC2        True           True          0.004831  -0.151
# FOSB         True           True          0.014845  -0.439
# OPA3         True           True          0.015761  -0.107
# QPCTL        True           True          0.012513  -0.147
# RELB         True           True          0.023933  -0.204
# RTN2         True           True          0.023954  -0.173
# SNRPD2       True           True          0.026898  -0.236
# TMEM126A     True           True          0.011462  -0.375
#
# Expected overlap count: 8
# Verified overlap count: 8

# %% [markdown]
# # 23: Confirm Sample Group Composition (Braak Stage & Brain Region)

# %%
print("Control samples verification:")
for gsm in control_samples:
    print(f"  {gsm} | Braak: {sample_braak[gsm]} | Region: {sample_titles[gsm].split('_')[-1].split(' ')[0]}")

print("\nAD samples verification:")
for gsm in ad_samples:
    print(f"  {gsm} | Braak: {sample_braak[gsm]} | Region: {sample_titles[gsm].split('_')[-1].split(' ')[0]}")
# Out:
# Control samples verification:
#   GSM3790983 | Braak: 0 | Region: EC
#   GSM3790986 | Braak: 0 | Region: EC
#   GSM3790989 | Braak: 0 | Region: EC
#   GSM3790992 | Braak: 0 | Region: EC
#   GSM3790995 | Braak: 0 | Region: EC
#   GSM3790998 | Braak: 0 | Region: EC
#   GSM3791001 | Braak: 0 | Region: EC
#   GSM3791004 | Braak: 0 | Region: EC
#   GSM3791007 | Braak: 0 | Region: EC
#   GSM3791010 | Braak: 0 | Region: EC
#   GSM3791013 | Braak: 0 | Region: EC
#   GSM3791016 | Braak: 0 | Region: EC
#   GSM3791019 | Braak: 0 | Region: EC
#
# AD samples verification:
#   GSM3791139 | Braak: V-VI | Region: EC
#   GSM3791142 | Braak: V-VI | Region: EC
#   GSM3791145 | Braak: V-VI | Region: EC
#   GSM3791148 | Braak: V-VI | Region: EC
#   GSM3791151 | Braak: V-VI | Region: EC
#   GSM3791154 | Braak: V-VI | Region: EC
#   GSM3791157 | Braak: V-VI | Region: EC
#   GSM3791160 | Braak: V-VI | Region: EC
#   GSM3791163 | Braak: V-VI | Region: EC
#   GSM3791166 | Braak: V-VI | Region: EC
#   GSM3791169 | Braak: V-VI | Region: EC
#   GSM3791172 | Braak: V-VI | Region: EC
#   GSM3791175 | Braak: V-VI | Region: EC
#   GSM3791178 | Braak: V-VI | Region: EC
#   GSM3791181 | Braak: V-VI | Region: EC
#   GSM3791184 | Braak: V-VI | Region: EC
#   GSM3791187 | Braak: V-VI | Region: EC
#   GSM3791190 | Braak: V-VI | Region: EC
#   GSM3791193 | Braak: V-VI | Region: EC

# %% [markdown]
# # 24: Spot-Check Normalization on Individual Probes

# %%
# Each ROW (probe) should have mean~0 across its 213 values
# Pick 5 random probes and check
import numpy as np
for i in [0, 100, 500, 1000, 5000]:
    row = geo_matrix_normalized.iloc[i, 1:].values
    print(f"Probe {i}: mean={row.mean():.4f}, std={row.std():.4f}")
# Out:
# Probe 0: mean=-0.0000, std=1.0000
# Probe 100: mean=0.0000, std=1.0000
# Probe 500: mean=-0.0000, std=1.0000
# Probe 1000: mean=-0.0000, std=1.0000
# Probe 5000: mean=-0.0000, std=1.0000

# %% [markdown]
# # 25: Pipeline Decision-Path Figure

# %%
# Visual walkthrough from raw data through every filtering/robustness step,
# auto-populated from variables already computed in this notebook.

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patches import FancyArrowPatch

fig, ax = plt.subplots(figsize=(14, 10))
ax.set_xlim(0, 10)
ax.set_ylim(0, 14)
ax.axis('off')

def box(x, y, w, h, text, color='#e8eef7'):
    rect = mpatches.FancyBboxPatch((x, y), w, h, boxstyle="round,pad=0.05",
                                    facecolor=color, edgecolor='black', linewidth=1)
    ax.add_patch(rect)
    ax.text(x + w/2, y + h/2, text, ha='center', va='center', fontsize=9, wrap=True)

def arrow(x1, y1, x2, y2):
    ax.add_patch(FancyArrowPatch((x1, y1), (x2, y2), arrowstyle='->',
                                  mutation_scale=15, color='black'))

# Main pipeline (left column)
box(0.5, 12.5, 3, 1, f"GWAS file\n({len(gwas_significant_df):,} sig. SNPs\np<5e-8)")
box(0.5, 11, 3, 1, f"GWAS→gene mapping\n(50kb window)\n→ {len(gwas_gene_set)} genes")
box(0.5, 9.5, 3, 1, f"Expression matrix\n({geo_matrix.shape[0]:,} probes,\n{len(control_samples)+len(ad_samples)} samples)")
box(0.5, 8, 3, 1, f"t-test DE analysis\np<0.05 (exploratory)\n→ {len(significant_genes)} probes\n→ {len(deg_gene_set)} genes")
box(0.5, 6.5, 3, 1, f"Set intersection\n→ {len(overlap_genes)} candidate genes", color='#f7e8e8')
box(0.5, 5, 3, 1, f"Full-DEG enrichment\n(n={len(deg_gene_set)})\n1 sig. KEGG term")

arrow(2, 12.5, 2, 12); arrow(2, 11, 2, 10.5)
arrow(2, 9.5, 2, 9); arrow(2, 8, 2, 7.5)
arrow(2, 6.5, 2, 6)

# Robustness checks (right column, branching off the intersection box)
box(4.5, 6.5, 5, 1, "ROBUSTNESS CHECKS", color='#fff3cd')
box(4.5, 5.2, 2.3, 1, f"Mann-Whitney\n{sum(1 for g in overlap_genes if g in mw_overlap)}/{len(overlap_genes)} confirmed")
box(7.2, 5.2, 2.3, 1, f"Hypergeometric\np={p_value:.3f}\n(caveat: LD)")
box(4.5, 3.9, 2.3, 1, f"LD/APOE clustering\n{len(overlap_genes)} genes →\n{independent_signal_count} loci")
box(7.2, 3.9, 2.3, 1, f"Mapping window\n{len(stable_genes)}/{len(overlap_genes)} stable\n(20-200kb)")

arrow(3.5, 7, 4.5, 7)
arrow(5.65, 6.5, 5.65, 6.2)
arrow(8.35, 6.5, 8.35, 6.2)
arrow(5.65, 5.2, 5.65, 4.9)
arrow(8.35, 5.2, 8.35, 4.9)

box(3, 2, 5, 1, f"Candidate-only enrichment (n={len(overlap_genes)})\n{len(sig_candidates)} nominal terms, 1 real (osteoclast diff.)", color='#f7e8e8')
arrow(6, 3.9, 5.5, 3)

ax.set_title("Multi-Omics Pipeline: Decision Path and Robustness Checks", fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('pipeline_decision_path.png', dpi=200, bbox_inches='tight')
plt.show()
print("Saved as 'pipeline_decision_path.png'")
# Out:
# Saved as 'pipeline_decision_path.png'

# %% [markdown]
# # 26: Consolidated Robustness Summary Table

# %%
# Shows, for each of the 8 original candidates, whether it survives
# under every robustness/sensitivity check performed.

summary_rows = []
for gene in sorted(overlap_genes):
    summary_rows.append({
        'Gene': gene,
        'Primary (t-test)': '✓',
        'Mann-Whitney U': '✓' if gene in mw_overlap else '✗',
        'LD-independent locus': '✓' if gene == 'TMEM126A' else 'clustered (chr19)',
        'Stable 20-200kb window': '✓' if gene in stable_genes else '✗',
    })

summary_df = pd.DataFrame(summary_rows)
print("=== CONSOLIDATED ROBUSTNESS SUMMARY ===\n")
print(summary_df.to_string(index=False))

summary_df.to_csv('robustness_summary.csv', index=False)
print("\nSaved as 'robustness_summary.csv'")

n_fully_robust = sum(
    1 for gene in overlap_genes
    if gene in mw_overlap and gene in stable_genes
)
print(f"\nGenes robust to BOTH the DE-method check AND the mapping-window check: {n_fully_robust}/{len(overlap_genes)}")
# Out:
# === CONSOLIDATED ROBUSTNESS SUMMARY ===
#
#     Gene Primary (t-test) Mann-Whitney U LD-independent locus Stable 20-200kb window
#    ERCC2                ✓              ✓    clustered (chr19)                      ✓
#     FOSB                ✓              ✓    clustered (chr19)                      ✓
#     OPA3                ✓              ✓    clustered (chr19)                      ✓
#    QPCTL                ✓              ✓    clustered (chr19)                      ✓
#     RELB                ✓              ✗    clustered (chr19)                      ✓
#     RTN2                ✓              ✓    clustered (chr19)                      ✓
#   SNRPD2                ✓              ✓    clustered (chr19)                      ✓
# TMEM126A                ✓              ✓                    ✓                      ✓
#
# Saved as 'robustness_summary.csv'
#
# Genes robust to BOTH the DE-method check AND the mapping-window check: 7/8

# %% [markdown]
# # 27: Extract All Available Sample Characteristics from Metadata

# %%
# Checks what covariates (age, sex, PMI, RIN, etc.) actually exist
# in the GSE131617 metadata for our 32 selected samples.

print("=== SCANNING METADATA FOR AVAILABLE COVARIATES ===\n")

characteristic_lines = []
with open("GSE131617-GPL5175_series_matrix.txt", "r") as f:
    for line in f:
        if line.startswith("!Sample_characteristics_ch1"):
            characteristic_lines.append(line.strip())
        if line.startswith('"ID_REF"') or line.startswith("ID_REF"):
            break

print(f"Number of characteristic rows found: {len(characteristic_lines)}\n")

# Each line is one *type* of characteristic across all 213 samples.
# Print the first value of each to see what fields exist.
for i, line in enumerate(characteristic_lines):
    values = re.findall(r'"([^"]+)"', line)
    if values:
        print(f"Field {i}: example value → '{values[0]}'")

print("\n" + "="*60)
print("If age, sex, PMI, or RIN do NOT appear above, they are simply")
print("not provided in this dataset's public metadata.")
print("="*60)
# Out:
# === SCANNING METADATA FOR AVAILABLE COVARIATES ===
#
# Number of characteristic rows found: 5
#
# Field 0: example value → 'subject id: BN_0_01'
# Field 1: example value → 'tissue: brain'
# Field 2: example value → 'tissue region: Entorhinal cortex (EC)'
# Field 3: example value → 'Sex: M'
# Field 4: example value → 'braak nft stage: 0'
#
# ============================================================
# If age, sex, PMI, or RIN do NOT appear above, they are simply
# not provided in this dataset's public metadata.
# ============================================================

# %% [markdown]
# # 27b: Check Sex Balance Between Control and AD Groups

# %%
# Sex is available in metadata (unlike age/PMI/RIN) — check for imbalance
# that could confound the Control vs AD comparison.

print("=== SEX DISTRIBUTION BY GROUP ===\n")

# Extract sex per sample from the metadata characteristic lines
sex_lines = [l for l in characteristic_lines if 'Sex:' in l]
sex_values = re.findall(r'"Sex:\s*([^"]+)"', sex_lines[0]) if sex_lines else []

# Build GSM -> sex lookup (same order as gsm_ids)
sample_sex = dict(zip(gsm_ids, sex_values))

# Count sex within each group
control_sex = [sample_sex.get(gsm, 'Unknown') for gsm in control_samples]
ad_sex = [sample_sex.get(gsm, 'Unknown') for gsm in ad_samples]

from collections import Counter
control_counts = Counter(control_sex)
ad_counts = Counter(ad_sex)

print(f"Control group (n={len(control_samples)}):")
for sex, count in control_counts.items():
    print(f"  {sex}: {count} ({count/len(control_samples)*100:.1f}%)")

print(f"\nAD group (n={len(ad_samples)}):")
for sex, count in ad_counts.items():
    print(f"  {sex}: {count} ({count/len(ad_samples)*100:.1f}%)")

# Chi-square test for independence (is sex distribution different between groups?)
from scipy.stats import chi2_contingency

all_sexes = sorted(set(control_sex) | set(ad_sex))
contingency = [
    [control_counts.get(s, 0) for s in all_sexes],
    [ad_counts.get(s, 0) for s in all_sexes]
]

print(f"\n{'='*50}")
print("Contingency table (rows=Control/AD, cols=" + ", ".join(all_sexes) + "):")
print(contingency)

chi2, p_chi, dof, expected = chi2_contingency(contingency)
print(f"\nChi-square test for sex-by-group independence:")
print(f"  Chi2 = {chi2:.3f}, p = {p_chi:.4f}")

if p_chi < 0.05:
    print("  → Sex distribution differs significantly between groups (potential confound).")
else:
    print("  → No significant sex imbalance detected between groups.")
# Out:
# === SEX DISTRIBUTION BY GROUP ===
#
# Control group (n=13):
#   M: 9 (69.2%)
#   F: 4 (30.8%)
#
# AD group (n=19):
#   M: 6 (31.6%)
#   F: 13 (68.4%)
#
# ==================================================
# Contingency table (rows=Control/AD, cols=F, M):
# [[4, 9], [13, 6]]
#
# Chi-square test for sex-by-group independence:
#   Chi2 = 3.012, p = 0.0826
#   → No significant sex imbalance detected between groups.

# %% [markdown]
# # 28: PCA Restricted to the 32 Analytical Samples

# %%
# Addresses Reviewer 2's request to see PCA computed on the actual
# 32-sample submatrix used for DE testing, not the full 213-sample set.

from sklearn.decomposition import PCA

print("=== PCA — 32 SELECTED SAMPLES ONLY ===\n")

analytical_samples = control_samples + ad_samples
submatrix = geo_matrix_normalized[analytical_samples].T  # 32 x 22011

pca32 = PCA(n_components=2)
coords32 = pca32.fit_transform(submatrix)

labels32 = ['Control'] * len(control_samples) + ['AD'] * len(ad_samples)
colors32 = ['blue'] * len(control_samples) + ['red'] * len(ad_samples)

plt.figure(figsize=(9, 7))
for label, color in [('Control', 'blue'), ('AD', 'red')]:
    mask = [l == label for l in labels32]
    pts = coords32[mask]
    plt.scatter(pts[:, 0], pts[:, 1], c=color, label=label, s=110,
                alpha=0.8, edgecolors='black')

plt.xlabel(f'PC1 ({pca32.explained_variance_ratio_[0]*100:.1f}% variance)', fontsize=12)
plt.ylabel(f'PC2 ({pca32.explained_variance_ratio_[1]*100:.1f}% variance)', fontsize=12)
plt.title('PCA Restricted to the 32 Analytical Samples\n(Braak 0 vs Braak V-VI, Entorhinal Cortex)',
          fontsize=13, fontweight='bold')
plt.legend(fontsize=10)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('pca_32samples_only.png', dpi=200)
plt.show()

print(f"PC1: {pca32.explained_variance_ratio_[0]*100:.1f}% variance")
print(f"PC2: {pca32.explained_variance_ratio_[1]*100:.1f}% variance")
print("Saved as 'pca_32samples_only.png'")
print("\nThis complements (not replaces) the earlier 213-sample PCA,")
print("which served a different purpose: global dataset QC.")
# Out:
# === PCA — 32 SELECTED SAMPLES ONLY ===
# PC1: 29.5% variance
# PC2: 15.2% variance
# Saved as 'pca_32samples_only.png'
#
# This complements (not replaces) the earlier 213-sample PCA,
# which served a different purpose: global dataset QC.

# %% [markdown]
# # 29: Capture Full Computational Environment

# %%
import sys, datetime
print(f"Python version: {sys.version}\n")
print(f"Notebook run date: {datetime.date.today()}")
print(f"Enrichr queries in this notebook were run on: {datetime.date.today()}")
# Out:
# Python version: 3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:38:37) [MSC v.1916 64 bit (AMD64)]
#
# Notebook run date: 2026-08-28
# Enrichr queries in this notebook were run on: 2026-08-28
